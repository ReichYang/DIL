# %%
import requests
import pandas as pd
import re
import lxml
from fake_useragent import UserAgent
from lxml import etree

# %%
requests.get("https://twitter.com/dillonbolding",headers=headers,stream=True).content
# Out:
# b'<!DOCTYPE html>\n<html lang="en" data-scribe-reduced-action-queue="true">\n  <head>\n    \n    \n    \n    \n    \n    \n    \n    <meta charset="utf-8">\n      <script  nonce="vadR0BYyl4rtI+oVIqjVEw==">\n        !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();\n      </script>\n    \n    \n  \n  <script id="bouncer_terminate_iframe" nonce="vadR0BYyl4rtI+oVIqjVEw==">\n    if (window.top != window) {\n  window.top.postMessage({\'bouncer\': true, \'event\': \'complete\'}, \'*\');\n}\n  </script>\n  <script id="ttft_boot_data" nonce="vadR0BYyl4rtI+oVIqjVEw==">\n    window.ttftData={"transaction_id":"00eb649100d3c244.8c4b7c298298e9db\\u003c:0002c58f0059c9ae","server_request_start_time":1550797699641,"user_id":null,"is_ssl":true,"rendered_on_server":true,"is_tfe":true,"client":"macaw-swift","tfe_version":"tsa_b\\/1.0.1\\/2019
# ...

# %%
user_db=pd.DataFrame()
user_pool=[]
failed=[]


failed_add=[]

# %%
ram=pd.read_csv("Copy of Silent Sam Tweets - Archive.csv")['from_user'][1501:].map(lambda x:user_pool.append("http://twitter.com/"+str(x) ))

# %%
urldb=pd.DataFrame(list(set(user_pool)), columns=["url"])

# %%
j=[j for j in range(1501,65000,1500)]
i=1501

# %%
ua = UserAgent()
headers = {'User-Agent': ua.random}

# %%
def get_node(user_id):
    global i
    global j
    
    try:
        #print(user_id)
        node=etree.HTML(requests.get(str(user_id),headers=headers,stream=True).content)
        if i in j:
            print(i, "user are done")
        
        i=i+1
        return node
        
    except e:
        failed.append(user)
        print("failed")

# %%
urldb["nodes"]=urldb['url'].map(get_node)
