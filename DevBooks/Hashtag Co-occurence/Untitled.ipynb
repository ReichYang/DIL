# %%
from twitterscraper import query_tweets

import datetime as dt
import pandas as pd

# %%
if __name__ == '__main__':
    list_of_tweets = query_tweets(begindate=dt.date(2016, 1, 1),enddate=dt.date(2019, 12, 31),query="#silentsam")
# Out:
# INFO: queries: ['#silentsam since:2016-01-01 until:2016-03-14', '#silentsam since:2016-03-14 until:2016-05-26', '#silentsam since:2016-05-26 until:2016-08-07', '#silentsam since:2016-08-07 until:2016-10-19', '#silentsam since:2016-10-19 until:2016-12-31', '#silentsam since:2016-12-31 until:2017-03-14', '#silentsam since:2017-03-14 until:2017-05-26', '#silentsam since:2017-05-26 until:2017-08-07', '#silentsam since:2017-08-07 until:2017-10-19', '#silentsam since:2017-10-19 until:2017-12-31', '#silentsam since:2017-12-31 until:2018-03-14', '#silentsam since:2018-03-14 until:2018-05-26', '#silentsam since:2018-05-26 until:2018-08-07', '#silentsam since:2018-08-07 until:2018-10-19', '#silentsam since:2018-10-19 until:2018-12-31', '#silentsam since:2018-12-31 until:2019-03-14', '#silentsam since:2019-03-14 until:2019-05-26', '#silentsam since:2019-05-26 until:2019-08-07', '#silentsam since:2019-08-07 until:2019-10-19', '#silentsam since:2019-10-19 until:2019-12-31']
# ...

# %%
tw=list_of_tweets[1]

# %%
file = open('output.txt','w')
for tweet in query_tweets(begindate=dt.date(2016, 1, 1),enddate=dt.date(2019, 12, 31),query="#silentsam"):
        file.write(tweet.encode('utf-8'))
file.close()
# Out:
# INFO: queries: ['#silentsam since:2016-01-01 until:2016-03-14', '#silentsam since:2016-03-14 until:2016-05-26', '#silentsam since:2016-05-26 until:2016-08-07', '#silentsam since:2016-08-07 until:2016-10-19', '#silentsam since:2016-10-19 until:2016-12-31', '#silentsam since:2016-12-31 until:2017-03-14', '#silentsam since:2017-03-14 until:2017-05-26', '#silentsam since:2017-05-26 until:2017-08-07', '#silentsam since:2017-08-07 until:2017-10-19', '#silentsam since:2017-10-19 until:2017-12-31', '#silentsam since:2017-12-31 until:2018-03-14', '#silentsam since:2018-03-14 until:2018-05-26', '#silentsam since:2018-05-26 until:2018-08-07', '#silentsam since:2018-08-07 until:2018-10-19', '#silentsam since:2018-10-19 until:2018-12-31', '#silentsam since:2018-12-31 until:2019-03-14', '#silentsam since:2019-03-14 until:2019-05-26', '#silentsam since:2019-05-26 until:2019-08-07', '#silentsam since:2019-08-07 until:2019-10-19', '#silentsam since:2019-10-19 until:2019-12-31']
# ...

# %%
df=pd.DataFrame()

# %%
for i in list_of_tweets:
    df=df.append(pd.DataFrame.from_dict([i.__dict__]))

# %%
df.to_csv("scrapper.csv",index_label=False)

# %%
df=df.append(pd.DataFrame.from_dict([i.__dict__]))

# %%
df
# Out:
#       screen_name                    username     user_id  \
# 0      amwhisnant  Dr. Anne Mitchell Whisnant    49497795
# 0   niiikkkiii_mn               Nikki Moazzen  4055910857
# 0     _thepopshop                The Pop Shop  1129817234
# 0   niiikkkiii_mn               Nikki Moazzen  4055910857
# 0     _thepopshop                The Pop Shop  1129817234
# ..            ...                         ...         ...
# 0           _LKC_                        Lori   190340855
# 0           _LKC_                        Lori   190340855
# 0           _LKC_                        Lori   190340855
# 0        yke_hmmm                        hmmm   103966638
# 0      amwhisnant  Dr. Anne Mitchell Whisnant    49497795
#
#                tweet_id                                 tweet_url  \
# 0   1027179347252269058    /amwhisnant/status/1027179347252269058
# 0    757052083728187396  /niiikkkiii_mn/status/757052083728187396
# 0    748218429761413120    /_thepopshop/status/748218429761413120
# ...
