# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import networkx as nx
import re
import numpy as np

# %%
db=pd.read_excel("Comprehensive TAGS v6.1.9, 2016-Feb 2019.xlsx",sheet_name=1)

# %% [markdown]
# Create a DataFrame containing each tweet's hashtages

# %%
tw_has=db.text.map(lambda x: re.findall(pattern=r"#\w+\w",string=x))

# %%
tw_has_time=pd.DataFrame([tw_has,db.created_at]).T

# %% [markdown]
# Convert it to a list

# %%
tw_has.tolist()
# Out:
# [['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#silentsam', '#philosophy'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#DTH126', '#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#silentsam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#Silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#silencesam',
#   '#rustinpiecessilentsam',
#   '#tarheelantifascism',
#   '#gdtbath',
#   '#silentsam',
#   '#antiracism',
#   '#fucktheconfederacy',
#   '#takeemdown',
#   '#strikedownsam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#silentsam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#northcarolina',
#   '#tarheels',
#   '#markharris',
#   '#republicans',
#   '#gop',
#   '#nc9',
#   '#nc09',
#   '#voterfraud',
#   '#absenteeballot',
#   '#gerrymandering',
#   '#racist',
#   '#unconstitutional',
#   '#uncchapelhill',
#   '#silentsam',
#   '#wpmot',
#   '#whatspissingmeofftoday'],
#  ['#SilentSam'],
#  ['#DTH126', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#unc',
#   '#silentsam',
#   '#takethemalldown',
#   '#nomonumentstowhitesupremacy',
#   '#OpKKK',
#   '#NoKKK',
#   '#FuckNeoConfeds'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#silentsam', '#antiracistsrunthistown'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#LastManStanding',
#   '#SilentSam',
#   '#HeirsOfTheConfederacy',
#   '#GoHomeRacists',
#   '#RunTheseRacistsOutOfTown'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#HeirsOfTheConfederacy', '#ChapelHill', '#UnitedStates', '#SilentSam'],
#  ['#SilentSam'],
#  ['#LastManStanding',
#   '#SilentSam',
#   '#HeirsOfTheConfederacy',
#   '#GoHomeRacists',
#   '#RunTheseRacistsOutOfTown'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#silentsam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#LastManStanding',
#   '#SilentSam',
#   '#HeirsOfTheConfederacy',
#   '#GoHomeRacists',
#   '#RunTheseRacistsOutOfTown'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#silentsam'],
#  ['#HeirsOfTheConfederacy', '#ChapelHill', '#UnitedStates', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam', '#dth126'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#silentsam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#silentsam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#World'],
#  ['#silentsam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#NeoConfederacy'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#LastManStanding',
#   '#SilentSam',
#   '#HeirsOfTheConfederacy',
#   '#GoHomeRacists',
#   '#RunTheseRacistsOutOfTown'],
#  ['#silentsam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#LastManStanding',
#   '#SilentSam',
#   '#HeirsOfTheConfederacy',
#   '#GoHomeRacists',
#   '#RunTheseRacistsOutOfTown'],
#  ['#SilentSam'],
#  ['#SilentSam', '#Confederacy'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#DTH126'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#silentsam'],
#  ['#SilentSam', '#StrikeDownSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#NorthCarolina', '#SilentSam', '#OpKKK', '#NoKKK', '#unc'],
#  ['#LastManStanding',
#   '#SilentSam',
#   '#HeirsOfTheConfederacy',
#   '#GoHomeRacists',
#   '#RunTheseRacistsOutOfTown'],
#  ['#silentsam'],
#  ['#SilenceSam', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#DTH126'],
#  ['#SilentSam'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#Confederacy'],
#  ['#SilentSam'],
#  ['#SilentSam', '#Confederacy'],
#  ['#SilentSam', '#UNC'],
#  ['#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#Confederate', '#SilentSam', '#NCPOL'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#MarkTwain',
#   '#SilentSam',
#   '#BeyondSilentSam',
#   '#UNC',
#   '#ChapelHill',
#   '#OrangeCounty'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#silentsam'],
#  ['#NCPol', '#MarkHarris', '#NC09', '#SilentSam'],
#  ['#SilentSam'],
#  ['#racists',
#   '#confederacy',
#   '#HeirsOfTheConfederacy',
#   '#ConfederateFlag',
#   '#SilentSam',
#   '#anti'],
#  ['#HiersOfTheConfederacy', '#silentsam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#Antifa', '#Left'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#NorthCarolina', '#SilentSam', '#OpKKK', '#NoKKK', '#unc'],
#  ['#SilentSam'],
#  ['#silentsam', '#WhiteSupremacists', '#VotingRights'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#MichaelJordan', '#SamPerkins', '#SilentSam', '#NorthCarolina', '#UNC'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam', '#silencesam', '#unc'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#MarkTwain',
#   '#Toastmasters',
#   '#919',
#   '#Raleigh',
#   '#ChapelHill',
#   '#WilmingtonNC',
#   '#ILM',
#   '#UNC',
#   '#outandabout',
#   '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam', '#silencesam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#WhiteSupremacy'],
#  ['#SilentSam', '#historicaltruth'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#blackhistorymonth',
#   '#day14',
#   '#silentsam',
#   '#confederatemonuments',
#   '#socialjustice'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#tcot'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam', '#silencesam', '#confederatesymbols'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam', '#abc11'],
#  ['#silentsam', '#silencesam'],
#  ['#silentsam',
#   '#everythinghasahistory',
#   '#publichistory',
#   '#digitalhumanities'],
#  ['#silentsam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#abc11'],
#  ['#silentsam', '#racism', '#monumentality'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam'],
#  ['#silentsam', '#monuments', '#history'],
#  ['#SilentSam', '#abc11'],
#  ['#NCPol', '#SilentSam'],
#  ['#silentsam',
#   '#everythinghasahistory',
#   '#publichistory',
#   '#digitalhumanities'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam'],
#  ['#silentsam',
#   '#everythinghasahistory',
#   '#publichistory',
#   '#digitalhumanities'],
#  ['#SilentSam'],
#  ['#SilentSam', '#UNC', '#ChapelHill', '#Confederate'],
#  ['#MayaLittle', '#SilentSam'],
#  ['#SilentSam', '#UNC'],
#  ['#SilentSam'],
#  ['#mayalittle', '#silentsam', '#silencesam'],
#  ['#silentsam',
#   '#everythinghasahistory',
#   '#publichistory',
#   '#digitalhumanities'],
#  ['#Confederate',
#   '#statues',
#   '#UNC',
#   '#MayaLittle',
#   '#protest',
#   '#SilentSam',
#   '#rallyingcry',
#   '#black',
#   '#queer',
#   '#WomensLiberation',
#   '#Women',
#   '#Transgender',
#   '#LGBTQIA'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam', '#abc11'],
#  ['#silentsam', '#silencesam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam'],
#  ['#UNCBoG', '#SilentSam', '#NCPol'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam', '#abc11'],
#  ['#Carrboro', '#BOA', '#truthplaque', '#SilentSam'],
#  ['#SilentSam', '#endracism'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#UNC'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#studentactivism'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam', '#abc11'],
#  ['#unc', '#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsamsyllabus',
#   '#monumentlab',
#   '#silentsam',
#   '#confederatemonuments',
#   '#monumentality'],
#  ['#publichistory', '#silentsam', '#twitterstorians'],
#  ['#SilentSam', '#abc11'],
#  ['#Carrboro', '#BOA', '#truthplaque', '#SilentSam'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam', '#blackface'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncpol', '#avlnews', '#SilentSam', '#VanceMonument'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncpol', '#avlnews', '#SilentSam', '#VanceMonument'],
#  ['#ncpol', '#avlnews', '#SilentSam', '#VanceMonument'],
#  ['#publichistory', '#silentsam', '#twitterstorians'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#Confederate',
#   '#statues',
#   '#UNC',
#   '#MayaLittle',
#   '#protest',
#   '#SilentSam',
#   '#rallyingcry',
#   '#black',
#   '#queer',
#   '#WomensLiberation',
#   '#Women',
#   '#Transgender',
#   '#LGBTQIA'],
#  ['#guesswho', '#itme', '#ityou', '#silentsam'],
#  ['#ncga', '#ncpol', '#SilentSam', '#blackface'],
#  ['#SilentSam'],
#  ['#academic', '#censorship', '#SilentSam', '#college', '#sports', '#course'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncpol', '#avlnews', '#SilentSam', '#VanceMonument'],
#  ['#SilentSam'],
#  ['#publichistory', '#silentsam', '#twitterstorians'],
#  ['#SilentSam'],
#  ['#Confederate',
#   '#statues',
#   '#UNC',
#   '#MayaLittle',
#   '#protest',
#   '#SilentSam',
#   '#rallyingcry',
#   '#black',
#   '#queer',
#   '#WomensLiberation',
#   '#Women',
#   '#Transgender',
#   '#LGBTQIA'],
#  ['#noexcuses', '#silentsam'],
#  ['#SilentSam'],
#  ['#silentsam', '#UNC'],
#  ['#ANTIFA', '#AntiRacistAction', '#Resist', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#publichistory', '#silentsam', '#twitterstorians'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam', '#UNC'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam', '#UNC'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam', '#UNC'],
#  ['#silentsam'],
#  ['#ncpol',
#   '#ncga',
#   '#NCed',
#   '#SilentSam',
#   '#StrongSchools',
#   '#CloseTheGapNC'],
#  ['#ncpol', '#avlnews', '#SilentSam', '#VanceMonument'],
#  ['#SilentSam', '#studentactivism'],
#  ['#SilentSam', '#abc11'],
#  ['#ConfederateMonuments', '#CivilWarMonuments', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#abc11'],
#  ['#SilentSam'],
#  ['#silentsam', '#UNC'],
#  ['#MarkTwain',
#   '#Toastmasters',
#   '#919',
#   '#Raleigh',
#   '#Wilmingtonnc',
#   '#ILM',
#   '#HiltonHead',
#   '#Kids',
#   '#Children',
#   '#SilentSam',
#   '#BeyondSilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#publichistory', '#silentsam', '#twitterstorians'],
#  ['#HKonJ', '#MoralMarch', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam', '#blackface'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SILENTSAM'],
#  ['#ncga', '#ncpol', '#SilentSam', '#blackface'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#HKonJ', '#MoralMarch', '#SilentSam'],
#  ['#SILENTsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SILENTSAM'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#HKonJ', '#MoralMarch', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncpol',
#   '#ncga',
#   '#ncgov',
#   '#UNC',
#   '#SilentSam',
#   '#HigherEd',
#   '#nced',
#   '#bluenc',
#   '#consnc',
#   '#ConfederateMonuments'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#UNC',
#   '#ChapelHill',
#   '#ncga',
#   '#ncpol',
#   '#ncgov',
#   '#SilentSam',
#   '#highered'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncpol',
#   '#ncga',
#   '#ncgov',
#   '#UNC',
#   '#SilentSam',
#   '#HigherEd',
#   '#nced',
#   '#bluenc',
#   '#consnc',
#   '#ConfederateMonuments'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#UNC',
#   '#ChapelHill',
#   '#ncga',
#   '#ncpol',
#   '#ncgov',
#   '#SilentSam',
#   '#highered'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncpol',
#   '#ncga',
#   '#ncgov',
#   '#UNC',
#   '#SilentSam',
#   '#HigherEd',
#   '#nced',
#   '#bluenc',
#   '#consnc',
#   '#ConfederateMonuments'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#blackface', '#UNC', '#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#USA',
#   '#Division2',
#   '#WhatMenWant',
#   '#kcwx',
#   '#PaceYourselves',
#   '#PelosiCap',
#   '#goodgirl',
#   '#JeffreeStarApproved',
#   '#WarriorsGround',
#   '#SilentSam',
#   '#BurgundyPodcast',
#   '#InTheDark',
#   '#CAS19'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#MakeItMakeSense'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#MakeItMakeSense'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#BlackHistoryMonth'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#silentsamsyllabus',
#   '#monumentlab',
#   '#silentsam',
#   '#confederatemonuments',
#   '#monumentality'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#ncga', '#ncpol', '#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam', '#BlackHistoryMonth'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#SilentSam'],
#  ['#KappaAlpha', '#SilentSam', '#UNC'],
#  ['#SilentSam'],
#  ...]

# %% [markdown]
# Flatten the lists of list

# %%
has_ls=[item.lower() for ls in tw_has.tolist() for item in ls ]

# %% [markdown]
# 102153 hashtags have been mentioned in the corpus

# %%
len(has_ls)
# Out:
# 102153

# %% [markdown]
# Create a Counter to count the occurance of each hashtages

# %%
from collections import Counter
Counter(has_ls).most_common(10)
# Out:
# [('#silentsam', 59709),
#  ('#unc', 10211),
#  ('#ncpol', 2947),
#  ('#silencesam', 2867),
#  ('#ncga', 1162),
#  ('#chapelhill', 1009),
#  ('#confederate', 870),
#  ('#wral', 689),
#  ('#strikedownsam', 658),
#  ('#abc11', 477)]

# %%
tw_has.reset_index()
# Out:
#        index                                               text
# 0          0                                       [#SilentSam]
# 1          1                                       [#silentsam]
# 2          2                                       [#SilentSam]
# 3          3  [#racists, #confederacy, #HeirsOfTheConfederac...
# 4          4                                       [#SilentSam]
# 5          5                          [#silentsam, #philosophy]
# 6          6                      [#SilentSam, #NeoConfederacy]
# 7          7                      [#SilentSam, #NeoConfederacy]
# 8          8                              [#DTH126, #SilentSam]
# 9          9  [#racists, #confederacy, #HeirsOfTheConfederac...
# 10        10                                       [#silentsam]
# 11        11                      [#SilentSam, #NeoConfederacy]
# 12        12                                       [#SilentSam]
# 13        13                                       [#SilentSam]
# 14        14                      [#SilentSam, #NeoConfederacy]
# 15        15                      [#SilentSam, #NeoConfederacy]
# 16        16                                       [#SilentSam]
# 17        17                      [#SilentSam, #NeoConfederacy]
# 18        18                                       [#SilentSam]
# 19        19                                       [#SilentSam]
# 20        20                                       [#Silentsam]
# 21        21                                       [#SilentSam]
# 22        22                      [#SilentSam, #NeoConfederacy]
# 23        23                                       [#SilentSam]
# 24        24                                       [#SilentSam]
# 25        25                      [#SilentSam, #NeoConfederacy]
# 26        26  [#racists, #confederacy, #HeirsOfTheConfederac...
# 27        27                                       [#silentsam]
# 28        28                                       [#SilentSam]
# 29        29                      [#SilentSam, #NeoConfederacy]
# ...      ...                                                ...
# 59224  59224                          [#wheresglen, #silentsam]
# 59225  59225                                       [#SilentSam]
# 59226  59226                [#artsandsocialjustice, #Silentsam]
# 59227  59227                                       [#SilentSam]
# 59228  59228                                       [#silentsam]
# 59229  59229  [#SilentSam, #ConfederateHeritageMonth, #twitt...
# 59230  59230                        [#SilentSam, #WilsonforSBP]
# 59231  59231                                       [#SilentSam]
# 59232  59232                        [#WilsonforSBP, #SilentSam]
# 59233  59233                                 [#SilentSam, #NHL]
# 59234  59234                     [#facilitatingSam, #silentSam]
# 59235  59235                     [#unc, #lostcause, #SilentSam]
# 59236  59236                                       [#SilentSam]
# 59237  59237                               [#Silentsam, #vodka]
# 59238  59238  [#beer, #wine, #heineken, #greekwine, #liquor,...
# 59239  59239                                       [#silentsam]
# 59240  59240                     [#silentsam, #TrustTheProcess]
# 59241  59241  [#silentsam, #vodkaface, #liquorpig, #warpig, ...
# 59242  59242                                       [#silentsam]
# 59243  59243                                       [#SilentSam]
# 59244  59244                                       [#silentsam]
# 59245  59245                                       [#SilentSam]
# 59246  59246                [#artsandsocialjustice, #Silentsam]
# 59247  59247                                       [#SilentSam]
# 59248  59248           [#Saturday, #night, #silentsam, #cheers]
# 59249  59249                        [#SilentSam, #WilsonforSBP]
# 59250  59250                                       [#SilentSam]
# 59251  59251  [#shot, #SilentSam, #GetYoWeedOn, #GrindBreak,...
# 59252  59252                                       [#silentsam]
# 59253  59253                                       [#SilentSam]
#
# [59254 rows x 2 columns]

# %% [markdown]
# Find all co-occurance

# %%
has_co=tw_has[tw_has.apply(lambda x: len(x)>1)]

# %%
d={}

# %%
def buildKeys(ls):
    for i in range(len(ls)):
        for j in range(i+1,len(ls)):
            a = ls[i].lower()
            b = ls[j].lower()
            d.setdefault(a,{}).setdefault(b,{}).setdefault("weight",0)
            d[a][b]['weight'] += 1
    for i in range(len(ls)-1,-1,-1):
        for j in range(i-1,-1,-1):
            a = ls[i].lower()
            b = ls[j].lower()
            d.setdefault(a,{}).setdefault(b,{}).setdefault("weight",0)
            d[a][b]['weight'] += 1

# %%
has_co.apply(buildKeys)
# Out:
# 3        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 11       None
# 14       None
# 15       None
# 17       None
# 22       None
# 25       None
# 26       None
# 29       None
# 30       None
# 42       None
# 43       None
# 44       None
# 51       None
# 52       None
# 55       None
# 57       None
# 59       None
# 60       None
# 62       None
# 64       None
# 65       None
# 69       None
# 70       None
# 72       None
#          ...
# 59204    None
# 59205    None
# 59206    None
# 59207    None
# 59208    None
# 59209    None
# 59211    None
# 59212    None
# 59215    None
# 59216    None
# 59218    None
# 59219    None
# 59221    None
# 59223    None
# 59224    None
# 59226    None
# 59229    None
# 59230    None
# 59232    None
# 59233    None
# 59234    None
# 59235    None
# 59237    None
# 59238    None
# 59240    None
# 59241    None
# 59246    None
# 59248    None
# 59249    None
# 59251    None
# Name: text, Length: 23884, dtype: object

# %%
len(d)
# Out:
# 2871

# %%
d
# Out:
# {'#racists': {'#confederacy': {'weight': 25},
#   '#heirsoftheconfederacy': {'weight': 25},
#   '#confederateflag': {'weight': 25},
#   '#silentsam': {'weight': 30},
#   '#anti': {'weight': 25},
#   '#racist': {'weight': 1},
#   '#rasism': {'weight': 1},
#   '#truestory': {'weight': 1},
#   '#whitesupremacists': {'weight': 1},
#   '#confederatemonuments': {'weight': 1},
#   '#fuckallyall': {'weight': 1}},
#  '#confederacy': {'#heirsoftheconfederacy': {'weight': 25},
#   '#confederateflag': {'weight': 25},
#   '#silentsam': {'weight': 98},
#   '#anti': {'weight': 25},
#   '#racists': {'weight': 25},
#   '#music': {'weight': 2},
#   '#unc': {'weight': 19},
#   '#whitesupremacy': {'weight': 6},
#   '#history': {'weight': 6},
#   '#northcarolina': {'weight': 5},
#   '#stupid': {'weight': 3},
#   '#political': {'weight': 3},
#   '#essay': {'weight': 1},
#   '#slave': {'weight': 2},
#   '#twitterstorians': {'weight': 1},
#   '#monuments': {'weight': 2},
#   '#southernpride': {'weight': 1},
#   '#disenfranchisement': {'weight': 1},
#   '#power': {'weight': 1},
#   '#historicalcontext': {'weight': 1},
#   '#historiography': {'weight': 1},
#   '#politics': {'weight': 1},
#   '#whitewashing': {'weight': 1},
#   '#denial': {'weight': 1},
#   '#shame': {'weight': 1},
#   '#atonement': {'weight': 1},
#   '#slavery': {'weight': 1},
#   '#dth': {'weight': 1},
#   '#civilwar': {'weight': 3},
#   '#secondcivilwar': {'weight': 1},
#   '#domainname': {'weight': 1},
#   '#confederate': {'weight': 10},
#   '#whitenationalism': {'weight': 1},
#   '#blackhistory': {'weight': 1},
#   '#race': {'weight': 2},
#   '#confederatemonument': {'weight': 1},
#   '#antifa': {'weight': 1},
#   '#chapelhill': {'weight': 4},
#   '#toughguy': {'weight': 1},
#   '#tcot': {'weight': 8},
#   '#maga': {'weight': 8},
#   '#racism': {'weight': 9},
#   '#ccot': {'weight': 8},
#   '#trumprally': {'weight': 8},
#   '#military': {'weight': 8},
#   '#veterans': {'weight': 8},
#   '#protesters': {'weight': 8},
#   '#monument': {'weight': 2},
#   '#nazism': {'weight': 8},
#   '#kkk': {'weight': 2},
#   '#nazi': {'weight': 1},
#   '#dearunc': {'weight': 1},
#   '#fergithell': {'weight': 2},
#   '#nclegis': {'weight': 2},
#   '#uncch': {'weight': 2},
#   '#ncpol': {'weight': 2},
#   '#heritagenothate': {'weight': 1},
#   '#northernaggression': {'weight': 1},
#   '#hatred': {'weight': 1},
#   '#heritage': {'weight': 1},
#   '#traitors': {'weight': 2},
#   '#universityofnorth': {'weight': 2}},
#  '#heirsoftheconfederacy': {'#confederateflag': {'weight': 25},
#   '#silentsam': {'weight': 33},
#   '#anti': {'weight': 25},
#   '#confederacy': {'weight': 25},
#   '#racists': {'weight': 25},
#   '#gohomeracists': {'weight': 6},
#   '#runtheseracistsoutoftown': {'weight': 6},
#   '#lastmanstanding': {'weight': 6},
#   '#chapelhill': {'weight': 2},
#   '#unitedstates': {'weight': 2}},
#  '#confederateflag': {'#silentsam': {'weight': 31},
#   '#anti': {'weight': 25},
#   '#heirsoftheconfederacy': {'weight': 25},
#   '#confederacy': {'weight': 25},
#   '#racists': {'weight': 25},
#   '#protest': {'weight': 2},
#   '#chapelhill': {'weight': 2}},
#  '#silentsam': {'#anti': {'weight': 25},
#   '#confederateflag': {'weight': 31},
#   '#heirsoftheconfederacy': {'weight': 33},
#   '#confederacy': {'weight': 98},
#   '#racists': {'weight': 30},
#   '#philosophy': {'weight': 1},
#   '#neoconfederacy': {'weight': 20},
#   '#dth126': {'weight': 5},
#   '#antiracism': {'weight': 5},
#   '#fucktheconfederacy': {'weight': 2},
#   '#takeemdown': {'weight': 50},
#   '#strikedownsam': {'weight': 658},
#   '#gdtbath': {'weight': 270},
#   '#tarheelantifascism': {'weight': 1},
#   '#rustinpiecessilentsam': {'weight': 1},
#   '#silencesam': {'weight': 2869},
#   '#wpmot': {'weight': 3},
#   '#whatspissingmeofftoday': {'weight': 3},
#   '#uncchapelhill': {'weight': 168},
#   '#unconstitutional': {'weight': 3},
#   '#racist': {'weight': 111},
#   '#gerrymandering': {'weight': 11},
#   '#absenteeballot': {'weight': 3},
#   '#voterfraud': {'weight': 6},
#   '#nc09': {'weight': 15},
#   '#nc9': {'weight': 7},
#   '#gop': {'weight': 24},
#   '#republicans': {'weight': 10},
#   '#markharris': {'weight': 4},
#   '#tarheels': {'weight': 144},
#   '#northcarolina': {'weight': 227},
#   '#takethemalldown': {'weight': 1},
#   '#nomonumentstowhitesupremacy': {'weight': 1},
#   '#opkkk': {'weight': 39},
#   '#nokkk': {'weight': 7},
#   '#fuckneoconfeds': {'weight': 2},
#   '#unc': {'weight': 10219},
#   '#hiersoftheconfederacy': {'weight': 10},
#   '#antiracistsrunthistown': {'weight': 1},
#   '#gohomeracists': {'weight': 6},
#   '#runtheseracistsoutoftown': {'weight': 6},
#   '#lastmanstanding': {'weight': 6},
#   '#unitedstates': {'weight': 3},
#   '#chapelhill': {'weight': 1012},
#   '#world': {'weight': 1},
#   '#ncpol': {'weight': 2948},
#   '#confederate': {'weight': 871},
#   '#beyondsilentsam': {'weight': 5},
#   '#orangecounty': {'weight': 29},
#   '#marktwain': {'weight': 16},
#   '#antifa': {'weight': 400},
#   '#left': {'weight': 100},
#   '#whitesupremacists': {'weight': 7},
#   '#votingrights': {'weight': 2},
#   '#samperkins': {'weight': 11},
#   '#michaeljordan': {'weight': 12},
#   '#outandabout': {'weight': 2},
#   '#ilm': {'weight': 3},
#   '#wilmingtonnc': {'weight': 3},
#   '#raleigh': {'weight': 16},
#   '#919': {'weight': 6},
#   '#toastmasters': {'weight': 9},
#   '#whitesupremacy': {'weight': 301},
#   '#historicaltruth': {'weight': 1},
#   '#confederatemonuments': {'weight': 229},
#   '#socialjustice': {'weight': 12},
#   '#day14': {'weight': 1},
#   '#blackhistorymonth': {'weight': 10},
#   '#tcot': {'weight': 55},
#   '#confederatesymbols': {'weight': 1},
#   '#abc11': {'weight': 478},
#   '#everythinghasahistory': {'weight': 14},
#   '#publichistory': {'weight': 203},
#   '#digitalhumanities': {'weight': 6},
#   '#racism': {'weight': 170},
#   '#monumentality': {'weight': 6},
#   '#ncga': {'weight': 1162},
#   '#monuments': {'weight': 23},
#   '#history': {'weight': 169},
#   '#mayalittle': {'weight': 470},
#   '#rallyingcry': {'weight': 3},
#   '#black': {'weight': 8},
#   '#queer': {'weight': 3},
#   '#womensliberation': {'weight': 3},
#   '#women': {'weight': 6},
#   '#transgender': {'weight': 4},
#   '#lgbtqia': {'weight': 3},
#   '#protest': {'weight': 106},
#   '#statues': {'weight': 15},
#   '#uncbog': {'weight': 161},
#   '#truthplaque': {'weight': 4},
#   '#boa': {'weight': 5},
#   '#carrboro': {'weight': 9},
#   '#endracism': {'weight': 10},
#   '#studentactivism': {'weight': 4},
#   '#monumentlab': {'weight': 5},
#   '#silentsamsyllabus': {'weight': 8},
#   '#twitterstorians': {'weight': 156},
#   '#blackface': {'weight': 5},
#   '#vancemonument': {'weight': 5},
#   '#avlnews': {'weight': 12},
#   '#ityou': {'weight': 1},
#   '#itme': {'weight': 1},
#   '#guesswho': {'weight': 1},
#   '#college': {'weight': 13},
#   '#sports': {'weight': 1},
#   '#course': {'weight': 1},
#   '#censorship': {'weight': 2},
#   '#academic': {'weight': 1},
#   '#noexcuses': {'weight': 1},
#   '#resist': {'weight': 136},
#   '#antiracistaction': {'weight': 1},
#   '#strongschools': {'weight': 1},
#   '#closethegapnc': {'weight': 1},
#   '#nced': {'weight': 143},
#   '#civilwarmonuments': {'weight': 3},
#   '#children': {'weight': 1},
#   '#kids': {'weight': 3},
#   '#hiltonhead': {'weight': 2},
#   '#moralmarch': {'weight': 3},
#   '#hkonj': {'weight': 3},
#   '#highered': {'weight': 146},
#   '#bluenc': {'weight': 31},
#   '#consnc': {'weight': 29},
#   '#ncgov': {'weight': 299},
#   '#burgundypodcast': {'weight': 1},
#   '#inthedark': {'weight': 1},
#   '#cas19': {'weight': 1},
#   '#warriorsground': {'weight': 1},
#   '#jeffreestarapproved': {'weight': 1},
#   '#goodgirl': {'weight': 1},
#   '#pelosicap': {'weight': 1},
#   '#paceyourselves': {'weight': 1},
#   '#kcwx': {'weight': 1},
#   '#whatmenwant': {'weight': 1},
#   '#division2': {'weight': 1},
#   '#usa': {'weight': 42},
#   '#makeitmakesense': {'weight': 2},
#   '#kappaalpha': {'weight': 3},
#   '#23': {'weight': 1},
#   '#nc': {'weight': 222},
#   '#yaketyyak': {'weight': 1},
#   '#dixpark': {'weight': 1},
#   '#registertovotenow': {'weight': 8},
#   '#bluetsunami2018': {'weight': 8},
#   '#borntohate': {'weight': 8},
#   '#trump': {'weight': 48},
#   '#tarheel': {'weight': 43},
#   '#motivate': {'weight': 3},
#   '#speaking': {'weight': 1},
#   '#raleighnc': {'weight': 3},
#   '#wral': {'weight': 689},
#   '#bogshame': {'weight': 1},
#   '#hb2': {'weight': 4},
#   '#fuckneoconfederates': {'weight': 2},
#   '#fuckthekkklan': {'weight': 2},
#   '#lancespivey': {'weight': 2},
#   '#jamesstachowiak': {'weight': 6},
#   '#imhereforit': {'weight': 2},
#   '#fightfightfight': {'weight': 2},
#   '#duel': {'weight': 2},
#   '#letthemfight': {'weight': 2},
#   '#faculty': {'weight': 2},
#   '#orderofthelongleafpine': {'weight': 1},
#   '#chancellor': {'weight': 1},
#   '#hb10': {'weight': 1},
#   '#monument': {'weight': 46},
#   '#americanhistory': {'weight': 4},
#   '#erasism': {'weight': 2},
#   '#repeathistory': {'weight': 2},
#   '#communists': {'weight': 7},
#   '#coloneleffinghamsraid': {'weight': 2},
#   '#amprog': {'weight': 2},
#   '#teaparty': {'weight': 2},
#   '#dnc': {'weight': 12},
#   '#allmustfall': {'weight': 1},
#   '#samsreckoning': {'weight': 27},
#   '#slaveowners': {'weight': 1},
#   '#dogs': {'weight': 2},
#   '#rtp': {'weight': 6},
#   '#bedford': {'weight': 4},
#   '#wake': {'weight': 4},
#   '#speak': {'weight': 4},
#   '#cigars': {'weight': 3},
#   '#durham': {'weight': 198},
#   '#919magazine': {'weight': 4},
#   '#ncstate': {'weight': 4},
#   '#sogso': {'weight': 14},
#   '#fairelections': {'weight': 1},
#   '#slipperyslope': {'weight': 1},
#   '#lifelonglearning': {'weight': 5},
#   '#mlkweekend': {'weight': 3},
#   '#artivism': {'weight': 2},
#   '#activistart': {'weight': 2},
#   '#ripsam': {'weight': 1},
#   '#trumpisaracist': {'weight': 1},
#   '#confederatestatues': {'weight': 83},
#   '#silentsam': {'weight': 922},
#   '#udc': {'weight': 36},
#   '#trumpshutdown': {'weight': 1},
#   '#mlk': {'weight': 82},
#   '#statue': {'weight': 64},
#   '#doitlikechapelhill': {'weight': 1},
#   '#antiracist': {'weight': 6},
#   '#notallmen': {'weight': 2},
#   '#politics': {'weight': 8},
#   '#politicslive': {'weight': 2},
#   '#nopolitics': {'weight': 2},
#   '#thala': {'weight': 2},
#   '#ajithkumar': {'weight': 2},
#   '#ajith': {'weight': 2},
#   '#ncbog': {'weight': 3},
#   '#بقايا_جثه_سفاره_الفاتيكان': {'weight': 1},
#   '#rip': {'weight': 3},
#   '#is': {'weight': 1},
#   '#manbij': {'weight': 1},
#   '#campusfreespeech': {'weight': 1},
#   '#leadership': {'weight': 3},
#   '#carolfolt': {'weight': 57},
#   '#mlkday': {'weight': 3},
#   '#fairmaps': {'weight': 7},
#   '#likes': {'weight': 1},
#   '#follo4follo': {'weight': 1},
#   '#modelling': {'weight': 1},
#   '#duke': {'weight': 26},
#   '#pressfreedom': {'weight': 13},
#   '#neverforget': {'weight': 6},
#   '#civilwar': {'weight': 64},
#   '#maga': {'weight': 217},
#   '#chtc': {'weight': 29},
#   '#readlocal': {'weight': 170},
#   '#sam': {'weight': 2},
#   '#slavery': {'weight': 49},
#   '#racialjustice': {'weight': 27},
#   '#youth': {'weight': 14},
#   '#safeschools': {'weight': 19},
#   '#cltcc': {'weight': 3},
#   '#nikond3400': {'weight': 2},
#   '#selves': {'weight': 2},
#   '#guns': {'weight': 2},
#   '#men': {'weight': 4},
#   '#white': {'weight': 4},
#   '#racetalk': {'weight': 1},
#   '#sirwalter': {'weight': 1},
#   '#slaveowner': {'weight': 1},
#   '#education': {'weight': 5},
#   '#aconversationaboutrace': {'weight': 1},
#   '#realtalk': {'weight': 2},
#   '#talkingrace': {'weight': 1},
#   '#p2': {'weight': 23},
#   '#ftp': {'weight': 27},
#   '#acab': {'weight': 26},
#   '#bog': {'weight': 135},
#   '#wakeforest': {'weight': 1},
#   '#firstfriday': {'weight': 1},
#   '#visitraleigh': {'weight': 2},
#   '#speaker': {'weight': 1},
#   '#civilwarmemory': {'weight': 369},
#   '#ncbonds': {'weight': 1},
#   '#acp': {'weight': 1},
#   '#thepetekalinershow': {'weight': 2},
#   '#uncboardofgovernors': {'weight': 2},
#   '#uncboardoftrustees': {'weight': 2},
#   '#yosemitesam': {'weight': 1},
#   '#activism': {'weight': 15},
#   '#actbac': {'weight': 39},
#   '#backbar': {'weight': 2},
#   '#humanitieshappyhour': {'weight': 2},
#   '#icymi': {'weight': 9},
#   '#jeffersondavis': {'weight': 5},
#   '#ncpolitics': {'weight': 6},
#   '#shame': {'weight': 17},
#   '#tgdgrandmediacon': {'weight': 3},
#   '#invoxtiduraar': {'weight': 2},
#   '#flyeaglesfly': {'weight': 2},
#   '#12daysofmagenta': {'weight': 2},
#   '#25daysofgiving': {'weight': 2},
#   '#besttrips2019': {'weight': 2},
#   '#anamericanoriginal': {'weight': 2},
#   '#cfbplayoff': {'weight': 3},
#   '#chromebook': {'weight': 2},
#   '#design': {'weight': 2},
#   '#createforacause': {'weight': 2},
#   '#crushedup': {'weight': 2},
#   '#dowhatyoucant': {'weight': 2},
#   '#fallontonight': {'weight': 2},
#   '#horizons': {'weight': 2},
#   '#pasapalabrachv': {'weight': 2},
#   '#humanitieshour': {'weight': 2},
#   '#silencedsam': {'weight': 275},
#   '#uncbot': {'weight': 42},
#   '#savestudentnewsrooms': {'weight': 3},
#   '#mondaymotivation': {'weight': 48},
#   '#rawmemphis': {'weight': 1},
#   '#cfbchampionship': {'weight': 1},
#   '#ausvind': {'weight': 1},
#   '#phivsno': {'weight': 1},
#   '#lacvsne': {'weight': 1},
#   '#nhlbruins': {'weight': 1},
#   '#royalrumble': {'weight': 1},
#   '#thebachelor': {'weight': 1},
#   '#memes': {'weight': 1},
#   '#abetterworldforpets': {'weight': 1},
#   '#2008v2018': {'weight': 1},
#   '#hartaberfair': {'weight': 1},
#   '#cordelencantado': {'weight': 1},
#   '#2009vs2019challenge': {'weight': 1},
#   '#boardofgovernors': {'weight': 4},
#   '#chancellorfolt': {'weight': 1},
#   '#snowflakes': {'weight': 18},
#   '#uncsystem': {'weight': 2},
#   '#dropthecharges': {'weight': 20},
#   '#uncalumni': {'weight': 45},
#   '#leader': {'weight': 1},
#   '#questionoftheday': {'weight': 4},
#   '#bogs': {'weight': 1},
#   '#standwithmaya': {'weight': 101},
#   '#goodnight': {'weight': 1},
#   '#goodnews': {'weight': 1},
#   '#marble': {'weight': 1},
#   '#pedestal': {'weight': 1},
#   '#tarheelnation': {'weight': 4},
#   '#breaking': {'weight': 113},
#   '#ahaatakeover': {'weight': 4},
#   '#monumentalcrisis': {'weight': 4},
#   '#confederatemonument': {'weight': 154},
#   '#iconoclasm': {'weight': 4},
#   '#noshero': {'weight': 1},
#   '#priorities': {'weight': 2},
#   '#magats': {'weight': 3},
#   '#qanon': {'weight': 48},
#   '#maga2020': {'weight': 5},
#   '#folt': {'weight': 3},
#   '#wccb': {'weight': 5},
#   '#ncnews': {'weight': 62},
#   '#update': {'weight': 9},
#   '#carrborovalentines': {'weight': 2},
#   '#directaction': {'weight': 10},
#   '#supportourtroops': {'weight': 1},
#   '#nicetiming': {'weight': 2},
#   '#police': {'weight': 10},
#   '#civilrights': {'weight': 34},
#   '#koch': {'weight': 6},
#   '#oilandgas': {'weight': 1},
#   '#justice4sam': {'weight': 23},
#   '#defundunc': {'weight': 1},
#   '#preservehistory': {'weight': 17},
#   '#learnyourhistory': {'weight': 1},
#   '#winstonsalemconfederate': {'weight': 58},
#   '#uncpol': {'weight': 11},
#   '#wsoctv': {'weight': 1},
#   '#45': {'weight': 1},
#   '#publicsculpture': {'weight': 2},
#   '#dotherightthing': {'weight': 9},
#   '#byebye': {'weight': 1},
#   '#abouttime': {'weight': 1},
#   '#institutionalization': {'weight': 1},
#   '#breakingnews': {'weight': 8},
#   '#morningjoe': {'weight': 23},
#   '#tuesdaythoughts': {'weight': 151},
#   '#carolchanning': {'weight': 3},
#   '#kenstarr': {'weight': 3},
#   '#jeromecorsi': {'weight': 3},
#   '#potus45': {'weight': 3},
#   '#potus': {'weight': 6},
#   '#scotus': {'weight': 3},
#   '#nato': {'weight': 3},
#   '#bigmac': {'weight': 3},
#   '#mcdonalds': {'weight': 3},
#   '#rotterdam': {'weight': 3},
#   '#infratech': {'weight': 3},
#   '#amsterdam': {'weight': 3},
#   '#01jokowilagi': {'weight': 3},
#   '#publicart': {'weight': 11},
#   '#tuesdaymorning': {'weight': 2},
#   '#mobrule': {'weight': 8},
#   '#nazifolt': {'weight': 1},
#   '#republican': {'weight': 4},
#   '#repsteveking': {'weight': 2},
#   '#whitesupremacist': {'weight': 10},
#   '#silentsamstump': {'weight': 1},
#   '#directactionworks': {'weight': 5},
#   '#uncc': {'weight': 3},
#   '#ushistory': {'weight': 12},
#   '#memory': {'weight': 21},
#   '#sonofsam': {'weight': 1},
#   '#trumprussia': {'weight': 4},
#   '#kabulblast': {'weight': 2},
#   '#shutdown2019': {'weight': 2},
#   '#muellerinvestigation': {'weight': 3},
#   '#yemengenocide': {'weight': 2},
#   '#rkelly': {'weight': 2},
#   '#rohingya': {'weight': 2},
#   '#syriawithdrawal': {'weight': 2},
#   '#silentcarol': {'weight': 2},
#   '#goheels': {'weight': 201},
#   '#news': {'weight': 67},
#   '#historicalcommission': {'weight': 1},
#   '#lawlessness': {'weight': 2},
#   '#thetarheeltruthcomesout': {'weight': 1},
#   '#smashwhitesupremacy': {'weight': 1},
#   '#takethemdown': {'weight': 29},
#   '#lynching': {'weight': 4},
#   '#winstonsalem': {'weight': 5},
#   '#goodoleboy': {'weight': 1},
#   '#hoodsoff': {'weight': 10},
#   '#fuckthekkk': {'weight': 5},
#   '#nonazis': {'weight': 39},
#   '#chickens': {'weight': 1},
#   '#electionresults': {'weight': 1},
#   '#chickenfarms': {'weight': 1},
#   '#sunshinelaws': {'weight': 1},
#   '#aha2019': {'weight': 92},
#   '#confederatestatue': {'weight': 79},
#   '#fakecoach': {'weight': 1},
#   '#fakeschool': {'weight': 2},
#   '#roy': {'weight': 1},
#   '#silentsamactionsession': {'weight': 3},
#   '#byyourlogic': {'weight': 1},
#   '#teachablemoment': {'weight': 17},
#   '#rapidresponsehistory': {'weight': 17},
#   '#ncudc': {'weight': 30},
#   '#aha19': {'weight': 34},
#   '#dtws': {'weight': 1},
#   '#wsnc': {'weight': 9},
#   '#spellcheck': {'weight': 4},
#   '#charlottesville': {'weight': 120},
#   '#humanrights': {'weight': 1},
#   '#apush': {'weight': 1},
#   '#activismisnotacrime': {'weight': 4},
#   '#feesmustfall': {'weight': 8},
#   '#southafrica': {'weight': 10},
#   '#uk': {'weight': 8},
#   '#student': {'weight': 8},
#   '#rhodesmustfall': {'weight': 8},
#   '#book': {'weight': 8},
#   '#acc': {'weight': 2},
#   '#newyears2019': {'weight': 5},
#   '#liberty': {'weight': 2},
#   '#intellectuallydishonest': {'weight': 1},
#   '#hypocrite': {'weight': 1},
#   '#bluedevils': {'weight': 1},
#   '#2018inreview': {'weight': 1},
#   '#affordablehousing': {'weight': 1},
#   '#tolls': {'weight': 1},
#   '#rachelwhiteread': {'weight': 2},
#   '#opdomesticterrorism': {'weight': 14},
#   '#knowyournazis': {'weight': 4},
#   '#makebigotsfamous': {'weight': 11},
#   '#hurricaneflorence': {'weight': 8},
#   '#heels': {'weight': 2},
#   '#moralmondays': {'weight': 1},
#   '#equity': {'weight': 1},
#   '#blue': {'weight': 1},
#   '#blm': {'weight': 29},
#   '#blackcommunity': {'weight': 1},
#   '#unify': {'weight': 1},
#   '#name': {'weight': 1},
#   '#ncedu': {'weight': 5},
#   '#raciststatue': {'weight': 7},
#   '#ncscv': {'weight': 31},
#   '#scv': {'weight': 44},
#   '#ncheros': {'weight': 2},
#   '#otd': {'weight': 4},
#   '#haycochrane': {'weight': 5},
#   '#andpeggy': {'weight': 3},
#   '#messy': {'weight': 7},
#   '#teamrhetoric': {'weight': 1},
#   '#nail': {'weight': 5},
#   '#1u': {'weight': 5},
#   '#tesla': {'weight': 5},
#   '#lyft': {'weight': 5},
#   '#uber': {'weight': 5},
#   '#belabored': {'weight': 5},
#   '#strikedownsamwe': {'weight': 5},
#   '#silencesolvesnothing': {'weight': 1},
#   '#haywoodcochrane': {'weight': 2},
#   '#bot': {'weight': 51},
#   '#silentsamstrike': {'weight': 69},
#   '#margaretspellings': {'weight': 2},
#   '#slaveholer': {'weight': 1},
#   '#hohoho': {'weight': 1},
#   '#gofundthewall': {'weight': 1},
#   '#marcussmith': {'weight': 1},
#   '#miredintheswamp': {'weight': 1},
#   '#factoryfarming': {'weight': 1},
#   '#mericasnum1shithole': {'weight': 1},
#   '#welcometonc': {'weight': 1},
#   '#festivus': {'weight': 2},
#   '#apple': {'weight': 3},
#   '#amazon': {'weight': 5},
#   '#voterid': {'weight': 7},
#   '#unifiedaction': {'weight': 1},
#   '#sjws': {'weight': 3},
#   '#shameonyou': {'weight': 17},
#   '#antihate': {'weight': 2},
#   '#myalmamater': {'weight': 2},
#   '#knowyournazi': {'weight': 2},
#   '#discriminacion': {'weight': 1},
#   '#xenophobia': {'weight': 1},
#   '#tuesdaymotivation': {'weight': 10},
#   '#stikedownsam': {'weight': 11},
#   '#twitterstorian': {'weight': 2},
#   '#historians': {'weight': 1},
#   '#endracismnow': {'weight': 2},
#   '#thread': {'weight': 8},
#   '#ncgop': {'weight': 111},
#   '#wellbeing': {'weight': 1},
#   '#482': {'weight': 1},
#   '#doublestandard': {'weight': 1},
#   '#blacklivesmatter': {'weight': 133},
#   '#communitystandards': {'weight': 1},
#   '#facebook': {'weight': 6},
#   '#sixtonesで妄想': {'weight': 4},
#   '#ハリポタ': {'weight': 4},
#   '#ガンプラ': {'weight': 4},
#   '#gawong': {'weight': 4},
#   '#がんばれ田中圭': {'weight': 4},
#   '#gajacyclone': {'weight': 4},
#   '#田中圭24時間テレビ': {'weight': 4},
#   '#mother': {'weight': 4},
#   '#渡り鳥レポート': {'weight': 4},
#   '#wwetlc': {'weight': 4},
#   '#nazis': {'weight': 1},
#   '#mccorkleplace': {'weight': 6},
#   '#megaphones': {'weight': 1},
#   '#honkers': {'weight': 1},
#   '#siren': {'weight': 1},
#   '#barricades': {'weight': 1},
#   '#uncbasketball': {'weight': 5},
#   '#glutenfree': {'weight': 4},
#   '#dixie': {'weight': 3},
#   '#namethattune': {'weight': 3},
#   '#unitetheright': {'weight': 7},
#   '#goodnightaltright': {'weight': 2},
#   '#bashthefash': {'weight': 1},
#   '#youknowwhattodo': {'weight': 5},
#   '#graduation': {'weight': 4},
#   '#deandome': {'weight': 4},
#   '#ocncarts': {'weight': 4},
#   '#tearitdown': {'weight': 26},
#   '#whitecomplicity': {'weight': 1},
#   '#music': {'weight': 12},
#   '#bennettcollege': {'weight': 38},
#   '#commemoration': {'weight': 3},
#   '#deansmith': {'weight': 4},
#   '#treason': {'weight': 3},
#   '#truth': {'weight': 60},
#   '#march2019': {'weight': 1},
#   '#state': {'weight': 1},
#   '#law': {'weight': 17},
#   '#historical': {'weight': 1},
#   '#zugzwang': {'weight': 3},
#   '#chess': {'weight': 3},
#   '#thirdreconstruction': {'weight': 6},
#   '#nation': {'weight': 1},
#   '#angumcheck': {'weight': 1},
#   '#roywilliams': {'weight': 3},
#   '#illegalaliens': {'weight': 3},
#   '#ms13': {'weight': 2},
#   '#nevergofullretard': {'weight': 1},
#   '#hypocrites': {'weight': 2},
#   '#jamesfields': {'weight': 7},
#   '#silentsamisnotmyunc': {'weight': 1},
#   '#unctarheelsbasketball': {'weight': 1},
#   '#civildisobedience': {'weight': 16},
#   '#freespeech': {'weight': 49},
#   '#roycooper': {'weight': 5},
#   '#win': {'weight': 3},
#   '#giveaway': {'weight': 1},
#   '#competition': {'weight': 1},
#   '#freebiefriday': {'weight': 1},
#   '#fridaymotivation': {'weight': 1},
#   '#fridaythoughts': {'weight': 2},
#   '#panthers': {'weight': 1},
#   '#buzzcity': {'weight': 1},
#   '#hornets': {'weight': 1},
#   '#thisisamerica': {'weight': 2},
#   '#academictwitter': {'weight': 5},
#   '#dedixifiecation': {'weight': 1},
#   '#volume11': {'weight': 1},
#   '#intersectionality': {'weight': 2},
#   '#leavemyheritagealone': {'weight': 1},
#   '#clarity': {'weight': 1},
#   '#assault': {'weight': 1},
#   '#incitingariot': {'weight': 1},
#   '#mayalittlemotion': {'weight': 1},
#   '#dejavu': {'weight': 3},
#   '#wikipedia': {'weight': 1},
#   '#university': {'weight': 20},
#   '#proworker': {'weight': 5},
#   '#huminfocus': {'weight': 1},
#   '#journomom': {'weight': 1},
#   '#life': {'weight': 1},
#   '#notsosilentwhenyoustandforhate': {'weight': 1},
#   '#marxists': {'weight': 1},
#   '#savebennett': {'weight': 7},
#   '#meltitdown': {'weight': 1},
#   '#parents': {'weight': 3},
#   '#withhold': {'weight': 1},
#   '#payments': {'weight': 1},
#   '#phd': {'weight': 1},
#   '#phdlife': {'weight': 1},
#   '#topplethemall': {'weight': 44},
#   '#dukebluedevils': {'weight': 2},
#   '#labor': {'weight': 4},
#   '#makehistoryatcarolina': {'weight': 1},
#   '#basketball': {'weight': 1},
#   '#solidarity': {'weight': 25},
#   '#jewish': {'weight': 3},
#   '#faith': {'weight': 3},
#   '#hornets30': {'weight': 1},
#   '#nba': {'weight': 1},
#   '#nccu': {'weight': 3},
#   '#mississippi': {'weight': 29},
#   '#bythenumbers': {'weight': 18},
#   '#athletes': {'weight': 11},
#   '#newsobserver': {'weight': 3},
#   '#justiceformarcussmith': {'weight': 23},
#   '#civitaspoll': {'weight': 26},
#   '#fuckwhitesupremacy': {'weight': 31},
#   '#stikedownsilentsam': {'weight': 1},
#   '#seriousinquiry': {'weight': 1},
#   '#crusades': {'weight': 6},
#   '#sjw': {'weight': 2},
#   '#studentprotest': {'weight': 1},
#   '#climatechange': {'weight': 1},
#   '#migrantcaravans': {'weight': 1},
#   '#france': {'weight': 1},
#   '#america': {'weight': 6},
#   '#poorpeoplescampaign': {'weight': 1},
#   '#therewerenogoodslaveholders': {'weight': 1},
#   '#memorialstoracism': {'weight': 1},
#   '#restinpiss': {'weight': 1},
#   '#blackfaculty': {'weight': 8},
#   '#silensam': {'weight': 1},
#   '#williamtecumsehsherman': {'weight': 1},
#   '#symbol': {'weight': 2},
#   '#moraltheology': {'weight': 3},
#   '#blktwitterstorians': {'weight': 16},
#   '#downwithsilentsam': {'weight': 6},
#   '#farmbureau': {'weight': 10},
#   '#wbtv': {'weight': 11},
#   '#wect': {'weight': 91},
#   '#wlos': {'weight': 66},
#   '#witn': {'weight': 38},
#   '#wtvd': {'weight': 111},
#   '#wunc': {'weight': 44},
#   '#gradestrike': {'weight': 1},
#   '#carolina': {'weight': 28},
#   '#sapro': {'weight': 1},
#   '#whitepowersam': {'weight': 8},
#   '#wit': {'weight': 1},
#   '#americansteamboat': {'weight': 1},
#   '#wisdom': {'weight': 1},
#   '#political': {'weight': 3},
#   '#stupid': {'weight': 4},
#   '#silentsamdebate': {'weight': 27},
#   '#southernheritage': {'weight': 1},
#   '#happiness': {'weight': 1},
#   '#strike': {'weight': 3},
#   '#teachingassistant': {'weight': 1},
#   '#highereducation': {'weight': 6},
#   '#essay': {'weight': 3},
#   '#shutitdown': {'weight': 29},
#   '#rt': {'weight': 4},
#   '#silent': {'weight': 4},
#   '#nojusticenopeace': {'weight': 49},
#   '#faccouncil': {'weight': 2},
#   '#phdchat': {'weight': 4},
#   '#doitlikedurham': {'weight': 320},
#   '#tearthemdown': {'weight': 16},
#   '#graduatestudents': {'weight': 1},
#   '#gradlife': {'weight': 1},
#   '#unctv': {'weight': 1},
#   '#slave': {'weight': 2},
#   '#refugees': {'weight': 7},
#   '#wipowergrab': {'weight': 7},
#   '#5millionplus': {'weight': 33},
#   '#equality': {'weight': 5},
#   '#justice': {'weight': 7},
#   '#coward': {'weight': 1},
#   '#burysilentsam': {'weight': 6},
#   '#fraud': {'weight': 2},
#   '#mccready': {'weight': 3},
#   '#harris': {'weight': 3},
#   '#election2018': {'weight': 3},
#   '#ballotharvesting': {'weight': 3},
#   '#electionfraud': {'weight': 5},
#   '#whitehouse': {'weight': 5},
#   '#democrats': {'weight': 17},
#   '#followbackresistance': {'weight': 8},
#   '#fbrparty': {'weight': 8},
#   '#fbr': {'weight': 12},
#   '#resistance': {'weight': 14},
#   '#ados': {'weight': 1},
#   '#dos': {'weight': 1},
#   '#academicmama': {'weight': 3},
#   '#property': {'weight': 6},
#   '#firstamendment': {'weight': 2},
#   '#strikethemdown': {'weight': 1},
#   '#goolsbysacrook': {'weight': 1},
#   '#recasthate': {'weight': 1},
#   '#carefulwhatyouwishfor': {'weight': 1},
#   '#racisminamerica': {'weight': 2},
#   '#blackpete': {'weight': 1},
#   '#peta': {'weight': 4},
#   '#yellowvests': {'weight': 1},
#   '#brexit': {'weight': 1},
#   '#tariffman': {'weight': 1},
#   '#jeffreyepstein': {'weight': 1},
#   '#russiagate': {'weight': 1},
#   '#flynnmemo': {'weight': 1},
#   '#mueller': {'weight': 2},
#   '#cia': {'weight': 1},
#   '#khashoggi': {'weight': 1},
#   '#whitaker': {'weight': 1},
#   '#doj': {'weight': 1},
#   '#cfpb': {'weight': 1},
#   '#fentanyl': {'weight': 1},
#   '#opioids': {'weight': 1},
#   '#georgehwbushfuneral': {'weight': 1},
#   '#irancontra': {'weight': 1},
#   '#mena': {'weight': 1},
#   '#cocaine': {'weight': 1},
#   '#respect': {'weight': 11},
#   '#rights': {'weight': 11},
#   '#wrongs': {'weight': 11},
#   '#crookedgoolsby': {'weight': 2},
#   '#clown': {'weight': 1},
#   '#unionstrength': {'weight': 1},
#   '#winning': {'weight': 10},
#   '#southrisingagain': {'weight': 1},
#   '#safespaced': {'weight': 1},
#   '#shithole': {'weight': 1},
#   '#presidentfuckface': {'weight': 1},
#   '#bebest': {'weight': 1},
#   '#gopcrooks': {'weight': 1},
#   '#bestof2018': {'weight': 1},
#   '#crowdfunding': {'weight': 1},
#   '#parenting': {'weight': 3},
#   '#ingrahamangle': {'weight': 2},
#   '#leftist': {'weight': 13},
#   '#military': {'weight': 9},
#   '#saufalcons': {'weight': 2},
#   '#shawu': {'weight': 2},
#   '#specmagradio': {'weight': 2},
#   '#specmagnc': {'weight': 2},
#   '#home': {'weight': 1},
#   '#crowdfundingcampaign': {'weight': 1},
#   '#violence': {'weight': 9},
#   '#prejudice': {'weight': 3},
#   '#hatecrimes': {'weight': 3},
#   '#uncforall': {'weight': 237},
#   '#disgusting': {'weight': 1},
#   '#occupysouthbuilding': {'weight': 2},
#   '#occupyunc': {'weight': 2},
#   '#uncch': {'weight': 149},
#   '#dh': {'weight': 5},
#   '#visualization': {'weight': 1},
#   '#socialnetworks': {'weight': 1},
#   '#savesomuchmoney': {'weight': 1},
#   '#generalsherman': {'weight': 4},
#   '#building': {'weight': 1},
#   '#trustees': {'weight': 1},
#   '#americans': {'weight': 1},
#   '#memorial': {'weight': 1},
#   '#gopack': {'weight': 5},
#   '#georgemoseshorton': {'weight': 2},
#   '#upcycling': {'weight': 3},
#   '#nashville': {'weight': 13},
#   '#florida': {'weight': 1},
#   '#georgia': {'weight': 1},
#   '#murica': {'weight': 1},
#   '#universityofnorthcarolina': {'weight': 31},
#   '#ncboe': {'weight': 1},
#   '#bush41': {'weight': 1},
#   '#whiteprivilege': {'weight': 7},
#   '#factcheck': {'weight': 2},
#   '#tearthemalldown': {'weight': 8},
#   '#whosestate': {'weight': 1},
#   '#ourstate': {'weight': 1},
#   '#johnbrown': {'weight': 1},
#   '#chtown18': {'weight': 2},
#   '#boyswhoworegrey': {'weight': 3},
#   '#boybye': {'weight': 2},
#   '#uncalum': {'weight': 7},
#   '#professor': {'weight': 2},
#   '#endwhitesupremacy': {'weight': 44},
#   '#jimcrowe': {'weight': 2},
#   '#ableism': {'weight': 1},
#   '#incomeinequality': {'weight': 1},
#   '#thefutureisaccessible': {'weight': 1},
#   '#wewillnotbesilenced': {'weight': 26},
#   '#readabook': {'weight': 2},
#   '#oldwell': {'weight': 3},
#   '#nosilentsam': {'weight': 3},
#   '#alumnus': {'weight': 1},
#   '#uncboycottgiving': {'weight': 1},
#   '#askahistorian': {'weight': 6},
#   '#myfox8': {'weight': 56},
#   '#zombieconfederatemonument': {'weight': 2},
#   '#nomoremonuments': {'weight': 3},
#   '#politicalontwitter': {'weight': 1},
#   '#theresistance': {'weight': 13},
#   '#whitesupremacyenshrined': {'weight': 6},
#   '#smh': {'weight': 1},
#   '#dismantlewhitesupremacy': {'weight': 3},
#   '#fascists': {'weight': 1},
#   '#intolerant': {'weight': 1},
#   '#decolonizingwealth': {'weight': 1},
#   '#stupidisasstupiddoes': {'weight': 1},
#   '#cbs17': {'weight': 40},
#   '#unhc': {'weight': 3},
#   '#art': {'weight': 5},
#   '#banksy': {'weight': 1},
#   '#whitegenocide': {'weight': 5},
#   '#kalergiplan': {'weight': 1},
#   '#itsokaytobewhite': {'weight': 2},
#   '#progress': {'weight': 3},
#   '#washingtonmonument': {'weight': 1},
#   '#gthc': {'weight': 2},
#   '#gobc': {'weight': 2},
#   '#teachingtool': {'weight': 1},
#   '#chattelslavery': {'weight': 1},
#   '#wasteofmoney': {'weight': 1},
#   '#folthall': {'weight': 1},
#   '#nchistory': {'weight': 7},
#   '#lincoln': {'weight': 2},
#   '#hourofcode': {'weight': 7},
#   '#shawnstadium': {'weight': 7},
#   '#iwishtheyhadgiftcardsfor': {'weight': 10},
#   '#carnivalschmovies': {'weight': 7},
#   '#musicmonday': {'weight': 7},
#   '#neverisnow': {'weight': 7},
#   '#illinois200': {'weight': 7},
#   '#blocklandcle18': {'weight': 7},
#   '#7yearsof5sos': {'weight': 10},
#   '#outnow': {'weight': 7},
#   '#albumeinstein': {'weight': 7},
#   '#video': {'weight': 9},
#   '#gocray': {'weight': 7},
#   '#pullitdown': {'weight': 2},
#   '#confederatetakedown': {'weight': 81},
#   '#justsayin': {'weight': 2},
#   '#trophyhunters': {'weight': 2},
#   '#confederateunc': {'weight': 6},
#   '#hoboheretic': {'weight': 1},
#   '#marketing101': {'weight': 1},
#   '#christmas': {'weight': 4},
#   '#ridiculous': {'weight': 1},
#   '#geez': {'weight': 1},
#   '#nasasocial': {'weight': 5},
#   '#newmusic': {'weight': 1},
#   '#clt250': {'weight': 1},
#   '#ourepiphanyjin': {'weight': 1},
#   '#cannabiscanada': {'weight': 1},
#   '#chocolate': {'weight': 1},
#   '#bars': {'weight': 1},
#   '#hiphop': {'weight': 1},
#   '#soundcloudrapper': {'weight': 1},
#   '#cannabiscommunity': {'weight': 1},
#   '#kag': {'weight': 42},
#   '#sully': {'weight': 2},
#   '#fiverr': {'weight': 1},
#   '#mondaymorning': {'weight': 3},
#   '#find_internet_service': {'weight': 1},
#   '#12daysofchristmas': {'weight': 1},
#   '#viasatauthorizedretailer': {'weight': 1},
#   '#durhamnc': {'weight': 26},
#   '#paulimurray': {'weight': 8},
#   '#enoughisenough': {'weight': 3},
#   '#evil': {'weight': 1},
#   '#reparations': {'weight': 4},
#   '#fullframetheater': {'weight': 32},
#   '#documentary': {'weight': 29},
#   '#womenlead': {'weight': 1},
#   '#neveravailable': {'weight': 1},
#   '#careermp': {'weight': 1},
#   '#onlythereforthephotoop': {'weight': 1},
#   '#redneckrevolt': {'weight': 1},
#   '#altright': {'weight': 7},
#   '#watch': {'weight': 8},
#   '#lostcause': {'weight': 15},
#   '#evoices': {'weight': 1},
#   '#tryhardreturnseffort': {'weight': 1},
#   '#wecansay': {'weight': 1},
#   '#dontyouremember': {'weight': 1},
#   '#orangecountync': {'weight': 9},
#   '#historymatters': {'weight': 19},
#   '#dialogue': {'weight': 1},
#   '#arts': {'weight': 1},
#   '#mutualaid': {'weight': 13},
#   '#mado': {'weight': 2},
#   '#townhall': {'weight': 2},
#   '#pittsburghsynagogue': {'weight': 8},
#   '#keepsamdown': {'weight': 218},
#   '#pakistan': {'weight': 6},
#   '#kickoutthekkk': {'weight': 34},
#   '#wherescarol': {'weight': 5},
#   '#abolishhonorcourt': {'weight': 20},
#   '#pittsburghshooting': {'weight': 2},
#   '#uncnppa': {'weight': 13},
#   '#nppa': {'weight': 13},
#   '#silentsamfilm': {'weight': 13},
#   '#sunday': {'weight': 1},
#   '#goodtimes': {'weight': 1},
#   '#madotownhall': {'weight': 2},
#   '#putnamadministration': {'weight': 2},
#   '#buildtogether': {'weight': 2},
#   '#epicfail': {'weight': 5},
#   '#honorsystem': {'weight': 12},
#   '#magabomber': {'weight': 1},
#   '#fbi': {'weight': 2},
#   '#justiceformayalittle': {'weight': 5},
#   '#dwaynedixon': {'weight': 12},
#   '#confederatemonumeny': {'weight': 1},
#   '#jamescates': {'weight': 8},
#   '#orwell1984': {'weight': 4},
#   '#ccot': {'weight': 20},
#   '#1a': {'weight': 4},
#   '#midterms2018': {'weight': 8},
#   '#alumniforum2018': {'weight': 2},
#   '#citeblackwomen': {'weight': 24},
#   '#moneytalks': {'weight': 2},
#   '#npc': {'weight': 1},
#   '#nowhitesupremacy': {'weight': 1},
#   '#campushistories': {'weight': 62},
#   '#cleartheair': {'weight': 2},
#   '#unclimatesurvey': {'weight': 2},
#   '#necessity': {'weight': 1},
#   '#participationtrophies': {'weight': 1},
#   '#ocbocc': {'weight': 2},
#   '#wegotthis': {'weight': 202},
#   '#amend': {'weight': 1},
#   '#vandals': {'weight': 4},
#   '#necessityclause': {'weight': 11},
#   '#carolinadelnorte': {'weight': 5},
#   '#christineblaseyfordisaliar': {'weight': 1},
#   '#istandwithlawandorder': {'weight': 1},
#   '#justletthestudentslearn': {'weight': 1},
#   '#mondaythoughts': {'weight': 1},
#   '#nationalpugday': {'weight': 1},
#   '#impeach45': {'weight': 1},
#   '#rougekillers': {'weight': 1},
#   '#racismistheheartattack': {'weight': 5},
#   '#courtsupport': {'weight': 16},
#   '#justiceforsam': {'weight': 1},
#   '#justice4silentsam': {'weight': 1},
#   '#crossexamination': {'weight': 2},
#   '#bodycamera': {'weight': 2},
#   '#nocopsnoklangetridofsilentsam': {'weight': 2},
#   '#racialcapitalism': {'weight': 2},
#   '#whatwasthereason': {'weight': 2},
#   '#trials': {'weight': 4},
#   '#bodycameras': {'weight': 4},
#   '#healing': {'weight': 3},
#   '#unc225': {'weight': 1},
#   '#race': {'weight': 50},
#   '#marktwainhouse': {'weight': 1},
#   '#hypocrisy': {'weight': 24},
#   '#drfraud': {'weight': 1},
#   '#southernhistory': {'weight': 49},
#   '#rustinpieces': {'weight': 5},
#   '#j711': {'weight': 5},
#   '#statuealreadyremoved': {'weight': 1},
#   '#firedwaynedixon': {'weight': 2},
#   '#boycottunc': {'weight': 163},
#   '#confederatelivesmatter': {'weight': 2},
#   '#movesilentsam': {'weight': 34},
#   '#cnn': {'weight': 8},
#   '#tarheelshame': {'weight': 2},
#   '#saturdaymorning': {'weight': 6},
#   '#foodstudies': {'weight': 4},
#   '#sacredpublicspaces': {'weight': 3},
#   '#context': {'weight': 4},
#   '#nashvillianswillknow': {'weight': 1},
#   '#campushistory': {'weight': 2},
#   '#punk': {'weight': 3},
#   '#mute': {'weight': 2},
#   '#sacredspaces': {'weight': 2},
#   '#gafs18': {'weight': 3},
#   '#foodhist': {'weight': 3},
#   '#envhist': {'weight': 3},
#   '#southern': {'weight': 6},
#   '#kkk': {'weight': 13},
#   '#kenanstadium': {'weight': 3},
#   '#chpd': {'weight': 3},
#   '#hughmcmanaway': {'weight': 2},
#   '#charlottestatue': {'weight': 1},
#   '#antiantifatuesday': {'weight': 1},
#   '#taxpayers': {'weight': 10},
#   '#monumentstotreason': {'weight': 1},
#   '#ladybirdband': {'weight': 1},
#   '#guardian': {'weight': 1},
#   '#ladybird': {'weight': 1},
#   '#comm206': {'weight': 3},
#   '#believechristine': {'weight': 1},
#   '#kavanaughhearings': {'weight': 1},
#   '#uncfree': {'weight': 2},
#   ...},
#  '#anti': {'#silentsam': {'weight': 25},
#   '#confederateflag': {'weight': 25},
#   '#heirsoftheconfederacy': {'weight': 25},
#   '#confederacy': {'weight': 25},
#   '#racists': {'weight': 25}},
#  '#philosophy': {'#silentsam': {'weight': 1}},
#  '#neoconfederacy': {'#silentsam': {'weight': 20}},
#  '#dth126': {'#silentsam': {'weight': 5}},
#  '#silencesam': {'#rustinpiecessilentsam': {'weight': 1},
#   '#tarheelantifascism': {'weight': 1},
#   '#gdtbath': {'weight': 71},
#   '#silentsam': {'weight': 2869},
#   '#antiracism': {'weight': 1},
#   '#fucktheconfederacy': {'weight': 1},
#   '#takeemdown': {'weight': 7},
#   '#strikedownsam': {'weight': 115},
#   '#unc': {'weight': 1230},
#   '#confederatesymbols': {'weight': 1},
#   '#mayalittle': {'weight': 67},
#   '#chtc': {'weight': 1},
#   '#p2': {'weight': 22},
#   '#ftp': {'weight': 14},
#   '#acab': {'weight': 2},
#   '#silentsamstump': {'weight': 1},
#   '#nc': {'weight': 69},
#   '#history': {'weight': 1},
#   '#dotherightthing': {'weight': 1},
#   '#northcarolina': {'weight': 6},
#   '#chapelhill': {'weight': 48},
#   '#smashwhitesupremacy': {'weight': 1},
#   '#takethemdown': {'weight': 5},
#   '#opkkk': {'weight': 26},
#   '#hoodsoff': {'weight': 7},
#   '#fuckneoconfeds': {'weight': 1},
#   '#fuckthekkk': {'weight': 4},
#   '#nonazis': {'weight': 31},
#   '#opdomesticterrorism': {'weight': 14},
#   '#knowyournazis': {'weight': 4},
#   '#makebigotsfamous': {'weight': 11},
#   '#jamesstachowiak': {'weight': 4},
#   '#raciststatue': {'weight': 7},
#   '#haycochrane': {'weight': 3},
#   '#andpeggy': {'weight': 3},
#   '#shameonyou': {'weight': 2},
#   '#knowyournazi': {'weight': 2},
#   '#nazis': {'weight': 1},
#   '#dixie': {'weight': 1},
#   '#unitetheright': {'weight': 1},
#   '#goodnightaltright': {'weight': 1},
#   '#bashthefash': {'weight': 1},
#   '#youknowwhattodo': {'weight': 2},
#   '#angumcheck': {'weight': 1},
#   '#publichistory': {'weight': 34},
#   '#whitesupremacy': {'weight': 135},
#   '#uncalumni': {'weight': 28},
#   '#tarheels': {'weight': 47},
#   '#ncpol': {'weight': 69},
#   '#fuckwhitesupremacy': {'weight': 2},
#   '#ncga': {'weight': 98},
#   '#carolina': {'weight': 19},
#   '#burysilentsam': {'weight': 6},
#   '#silentsamstrike': {'weight': 2},
#   '#occupysouthbuilding': {'weight': 2},
#   '#occupyunc': {'weight': 2},
#   '#blacklivesmatter': {'weight': 56},
#   '#silencedsam': {'weight': 108},
#   '#standwithmaya': {'weight': 34},
#   '#courtsupport': {'weight': 3},
#   '#justiceformayalittle': {'weight': 1},
#   '#keepsamdown': {'weight': 92},
#   '#hatecrime': {'weight': 92},
#   '#back': {'weight': 51},
#   '#mlk': {'weight': 59},
#   '#wral': {'weight': 114},
#   '#wtvd': {'weight': 91},
#   '#bog': {'weight': 59},
#   '#ncgop': {'weight': 92},
#   '#dailytarheel': {'weight': 82},
#   '#wect': {'weight': 74},
#   '#wway': {'weight': 70},
#   '#ap': {'weight': 36},
#   '#confederatetakedown': {'weight': 12},
#   '#abolishpolice': {'weight': 4},
#   '#ncresists': {'weight': 1},
#   '#wlos': {'weight': 55},
#   '#emptyfoodpantry': {'weight': 1},
#   '#fooddrivenaway': {'weight': 1},
#   '#noluckpotluck': {'weight': 1},
#   '#witn': {'weight': 29},
#   '#touchthespider': {'weight': 1},
#   '#durham': {'weight': 3},
#   '#doitlikedurham': {'weight': 33},
#   '#tearthemdown': {'weight': 7},
#   '#confederatemonuments': {'weight': 15},
#   '#fuckchapelhill': {'weight': 2},
#   '#civilwarmemory': {'weight': 3},
#   '#wunc': {'weight': 33},
#   '#removesilentsam': {'weight': 1},
#   '#silencesamstump': {'weight': 1},
#   '#civildisobedience': {'weight': 4},
#   '#uncforall': {'weight': 58},
#   '#staydown': {'weight': 3},
#   '#goheels': {'weight': 70},
#   '#universityofnorthcarolina': {'weight': 3},
#   '#lumsontwitter': {'weight': 1},
#   '#silent': {'weight': 2},
#   '#campushistory': {'weight': 1},
#   '#keepgivingtheseracistmfershell': {'weight': 1},
#   '#seniorcitizenday': {'weight': 1},
#   '#catholicmetoo': {'weight': 1},
#   '#tuesdaythoughts': {'weight': 5},
#   '#loudandobnoxiousdonald': {'weight': 3},
#   '#confederate': {'weight': 110},
#   '#racism': {'weight': 11},
#   '#theresistance': {'weight': 1},
#   '#udc': {'weight': 1},
#   '#bigotry': {'weight': 1},
#   '#daughtersoftheconfederacy': {'weight': 1},
#   '#maga': {'weight': 1},
#   '#thefive': {'weight': 1},
#   '#realdonaldtrump': {'weight': 1},
#   '#imwithher': {'weight': 1},
#   '#metoo': {'weight': 1},
#   '#lifesabeach': {'weight': 1},
#   '#howtocatchanintrovert': {'weight': 1},
#   '#stfu': {'weight': 1},
#   '#breakingnews': {'weight': 1},
#   '#roseallday': {'weight': 1},
#   '#winelover': {'weight': 1},
#   '#wine': {'weight': 1},
#   '#solidarity': {'weight': 1},
#   '#statues': {'weight': 1},
#   '#ourstreet': {'weight': 6},
#   '#resist': {'weight': 4},
#   '#rebellionsarebuiltonhope': {'weight': 1},
#   '#ibelievethatwewillwin': {'weight': 1},
#   '#samsilenced': {'weight': 1},
#   '#ivegotyourpack': {'weight': 1},
#   '#alumna': {'weight': 1},
#   '#rrr': {'weight': 3},
#   '#tripler': {'weight': 3},
#   '#action': {'weight': 3},
#   '#noracistnc': {'weight': 3},
#   '#makeitright': {'weight': 3},
#   '#uncwhitesupremacy': {'weight': 1},
#   '#unchypocrisy': {'weight': 1},
#   '#uncracism': {'weight': 1},
#   '#comeoncarol': {'weight': 6},
#   '#mayaweloveyou': {'weight': 44},
#   '#campushistories': {'weight': 7},
#   '#fuckyostatue': {'weight': 2},
#   '#nonewkkk': {'weight': 2},
#   '#takeitdown': {'weight': 9},
#   '#itsabitcoinmine': {'weight': 2},
#   '#racist': {'weight': 79},
#   '#movesilentsam': {'weight': 21},
#   '#nchistory': {'weight': 1},
#   '#takeemdownnola': {'weight': 1},
#   '#silentsam17': {'weight': 2},
#   '#readtheletter': {'weight': 1},
#   '#confederatestatue': {'weight': 5},
#   '#civilrights': {'weight': 13},
#   '#ncbog': {'weight': 1},
#   '#harkthedrum': {'weight': 1},
#   '#toxicracialclimate': {'weight': 1},
#   '#uncbog': {'weight': 8},
#   '#truecolors': {'weight': 6},
#   '#jimcrow': {'weight': 1},
#   '#confederatestatues': {'weight': 10},
#   '#whiteprivilege': {'weight': 1},
#   '#intersectional': {'weight': 1},
#   '#forwardtogether': {'weight': 1},
#   '#juliancarr': {'weight': 1},
#   '#aycockhall': {'weight': 1},
#   '#jeffersondavishighway': {'weight': 1},
#   '#slaveryuva': {'weight': 2},
#   '#boycottunc': {'weight': 64},
#   '#beatuva': {'weight': 7},
#   '#originofflight': {'weight': 7},
#   '#blktwitterstorians': {'weight': 5},
#   '#twitterstorians': {'weight': 7},
#   '#ncudc': {'weight': 5},
#   '#noalthistory': {'weight': 2},
#   '#universityday': {'weight': 6},
#   '#nohateinourstate': {'weight': 3},
#   '#universityday2017': {'weight': 4},
#   '#heroes': {'weight': 3},
#   '#althistory': {'weight': 1},
#   '#stopracism': {'weight': 5},
#   '#defenddurham': {'weight': 19},
#   '#winning': {'weight': 3},
#   '#downwiththeconfederacy': {'weight': 1},
#   '#kickoutthekkk': {'weight': 1},
#   '#confederatemonumentsmustgo': {'weight': 1},
#   '#endracism': {'weight': 1},
#   '#now': {'weight': 1},
#   '#defendcivilrights': {'weight': 20},
#   '#uncboycott': {'weight': 1},
#   '#poll': {'weight': 3},
#   '#questionoftheday': {'weight': 3},
#   '#kkk': {'weight': 1},
#   '#throwthebumsout': {'weight': 1},
#   '#cacerolazo': {'weight': 4},
#   '#whitesupremacist': {'weight': 2},
#   '#carolinaconversations': {'weight': 1},
#   '#tarheel': {'weight': 6},
#   '#beyondtheheadlines': {'weight': 13},
#   '#violence': {'weight': 2},
#   '#lastsemester': {'weight': 2},
#   '#cal': {'weight': 1},
#   '#tarheelnation': {'weight': 1},
#   '#carolinaexperience': {'weight': 1},
#   '#confederatepride': {'weight': 1},
#   '#protest': {'weight': 1},
#   '#college': {'weight': 1},
#   '#loveoverhate': {'weight': 1},
#   '#sitinatunc': {'weight': 6},
#   '#sitin': {'weight': 5},
#   '#silentsamprotest': {'weight': 6},
#   '#newbluehand': {'weight': 1},
#   '#bluehand': {'weight': 1},
#   '#antifa': {'weight': 1},
#   '#whereiscarol': {'weight': 11},
#   '#periscope': {'weight': 10},
#   '#silencesam': {'weight': 4},
#   '#noconfederate': {'weight': 3},
#   '#nokkk': {'weight': 3},
#   '#nonazi': {'weight': 3},
#   '#freespeech': {'weight': 1},
#   '#campusy': {'weight': 1}},
#  '#rustinpiecessilentsam': {'#tarheelantifascism': {'weight': 1},
#   '#gdtbath': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#antiracism': {'weight': 1},
#   '#fucktheconfederacy': {'weight': 1},
#   '#takeemdown': {'weight': 1},
#   '#strikedownsam': {'weight': 1},
#   '#silencesam': {'weight': 1}},
#  '#tarheelantifascism': {'#gdtbath': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#antiracism': {'weight': 1},
#   '#fucktheconfederacy': {'weight': 1},
#   '#takeemdown': {'weight': 1},
#   '#strikedownsam': {'weight': 1},
#   '#rustinpiecessilentsam': {'weight': 1},
#   '#silencesam': {'weight': 1}},
#  '#gdtbath': {'#silentsam': {'weight': 270},
#   '#antiracism': {'weight': 1},
#   '#fucktheconfederacy': {'weight': 1},
#   '#takeemdown': {'weight': 1},
#   '#strikedownsam': {'weight': 1},
#   '#tarheelantifascism': {'weight': 1},
#   '#rustinpiecessilentsam': {'weight': 1},
#   '#silencesam': {'weight': 71},
#   '#topplethemall': {'weight': 44},
#   '#carolina': {'weight': 1},
#   '#unc225': {'weight': 1},
#   '#healing': {'weight': 1},
#   '#foodstudies': {'weight': 4},
#   '#dh': {'weight': 4},
#   '#unc': {'weight': 66},
#   '#uncforall': {'weight': 101},
#   '#whitesupremacy': {'weight': 26},
#   '#mythoughts': {'weight': 3},
#   '#silencedsam': {'weight': 3},
#   '#fdoc': {'weight': 2},
#   '#campushistories': {'weight': 23},
#   '#publichistory': {'weight': 23},
#   '#silentsamtoppled': {'weight': 2},
#   '#uncalumna': {'weight': 4},
#   '#blktwitterstorians': {'weight': 3},
#   '#silencethesam': {'weight': 1},
#   '#wral': {'weight': 1},
#   '#racism': {'weight': 2},
#   '#goheelsgoamerica': {'weight': 2},
#   '#goheels': {'weight': 124},
#   '#uncalumni': {'weight': 37},
#   '#uncspies': {'weight': 2},
#   '#unclies': {'weight': 2},
#   '#aycockhall': {'weight': 4},
#   '#jeffersondavishighway': {'weight': 4},
#   '#beatuva': {'weight': 7},
#   '#originofflight': {'weight': 7},
#   '#boycottunc': {'weight': 46},
#   '#ncpol': {'weight': 37},
#   '#ncga': {'weight': 26},
#   '#unc21': {'weight': 1},
#   '#unc20': {'weight': 1},
#   '#unc19': {'weight': 1},
#   '#unc18': {'weight': 1},
#   '#artseverywhereunc': {'weight': 8},
#   '#religionnerd': {'weight': 1},
#   '#proudalumnni': {'weight': 1},
#   '#uva200': {'weight': 3},
#   '#getrealwithbsm': {'weight': 2},
#   '#confederate': {'weight': 35},
#   '#spellingscommission': {'weight': 1},
#   '#defenddurham': {'weight': 12},
#   '#racist': {'weight': 10},
#   '#beatduke': {'weight': 2},
#   '#firstdayoffall': {'weight': 1},
#   '#blacklivesmatter': {'weight': 10},
#   '#beatodu': {'weight': 1},
#   '#tarheels': {'weight': 4},
#   '#alum': {'weight': 1},
#   '#replaceitwithdean': {'weight': 1}},
#  '#antiracism': {'#fucktheconfederacy': {'weight': 1},
#   '#takeemdown': {'weight': 1},
#   '#strikedownsam': {'weight': 1},
#   '#silentsam': {'weight': 5},
#   '#gdtbath': {'weight': 1},
#   '#tarheelantifascism': {'weight': 1},
#   '#rustinpiecessilentsam': {'weight': 1},
#   '#silencesam': {'weight': 1},
#   '#resist': {'weight': 2},
#   '#directactionworks': {'weight': 2},
#   '#unc': {'weight': 2},
#   '#negligent': {'weight': 2},
#   '#racist': {'weight': 2},
#   '#whitesupremacist': {'weight': 2},
#   '#mayalittle': {'weight': 2},
#   '#dropallcharges': {'weight': 2},
#   '#northcarolina': {'weight': 2},
#   '#chapelhill': {'weight': 2}},
#  '#fucktheconfederacy': {'#takeemdown': {'weight': 1},
#   '#strikedownsam': {'weight': 1},
#   '#antiracism': {'weight': 1},
#   '#silentsam': {'weight': 2},
#   '#gdtbath': {'weight': 1},
#   '#tarheelantifascism': {'weight': 1},
#   '#rustinpiecessilentsam': {'weight': 1},
#   '#silencesam': {'weight': 1},
#   '#spoilers': {'weight': 1},
#   '#getoverit': {'weight': 1},
#   '#fuckyourracism': {'weight': 1},
#   '#unc': {'weight': 1}},
#  '#takeemdown': {'#strikedownsam': {'weight': 1},
#   '#fucktheconfederacy': {'weight': 1},
#   '#antiracism': {'weight': 1},
#   '#silentsam': {'weight': 50},
#   '#gdtbath': {'weight': 1},
#   '#tarheelantifascism': {'weight': 1},
#   '#rustinpiecessilentsam': {'weight': 1},
#   '#silencesam': {'weight': 7},
#   '#unc': {'weight': 3},
#   '#takeemalldown': {'weight': 5},
#   '#charlottesville': {'weight': 5},
#   '#whitesupremacy': {'weight': 3},
#   '#blacklivesmatter': {'weight': 5},
#   '#racism': {'weight': 3},
#   '#takeitdown': {'weight': 2},
#   '#takethemdown': {'weight': 2},
#   '#blm': {'weight': 2},
#   '#surj': {'weight': 2},
#   '#changethename': {'weight': 2},
#   '#thetimeisnow': {'weight': 4},
#   '#nohateinourstate': {'weight': 1},
#   '#ncpol': {'weight': 1}},
#  '#strikedownsam': {'#takeemdown': {'weight': 1},
#   '#fucktheconfederacy': {'weight': 1},
#   '#antiracism': {'weight': 1},
#   '#silentsam': {'weight': 658},
#   '#gdtbath': {'weight': 1},
# ...
#   '#tcot': {'weight': 4},
#   '#ccot': {'weight': 4},
#   '#orwell1984': {'weight': 4},
#   '#silentsam': {'weight': 4}},
#  '#midterms2018': {'#maga': {'weight': 4},
#   '#1a': {'weight': 4},
#   '#racism': {'weight': 8},
#   '#tcot': {'weight': 4},
#   '#ccot': {'weight': 4},
#   '#orwell1984': {'weight': 4},
#   '#silentsam': {'weight': 8},
#   '#apt28': {'weight': 4},
#   '#lemonade': {'weight': 4},
#   '#nys': {'weight': 4},
#   '#ballstonspa': {'weight': 4},
#   '#brendanmulvaney': {'weight': 4},
#   '#cuomo': {'weight': 4},
#   '#russia': {'weight': 4},
#   '#hackers': {'weight': 4},
#   '#fancybear': {'weight': 4},
#   '#microsoft': {'weight': 4},
#   '#chapelhill': {'weight': 4},
#   '#confederatestatue': {'weight': 4},
#   '#confederate': {'weight': 4},
#   '#universityofnorthcarolina': {'weight': 4},
#   '#art': {'weight': 1}},
#  '#alumniforum2018': {'#silentsam': {'weight': 2}},
#  '#citeblackwomen': {'#silentsam': {'weight': 24},
#   '#standwithmaya': {'weight': 3},
#   '#twitterstorians': {'weight': 21},
#   '#confederatemonument': {'weight': 21},
#   '#followwomenwednesday': {'weight': 21}},
#  '#moneytalks': {'#silentsam': {'weight': 2}},
#  '#npc': {'#silentsam': {'weight': 1}, '#unc': {'weight': 1}},
#  '#nowhitesupremacy': {'#unc': {'weight': 1}, '#silentsam': {'weight': 1}},
#  '#campushistories': {'#silentsam': {'weight': 62},
#   '#context': {'weight': 4},
#   '#publichistory': {'weight': 47},
#   '#gdtbath': {'weight': 23},
#   '#blackatbrynmawr': {'weight': 2},
#   '#historicsites': {'weight': 10},
#   '#museums': {'weight': 10},
#   '#nationalparks': {'weight': 10},
#   '#unc': {'weight': 24},
#   '#silencesam': {'weight': 7}},
#  '#cleartheair': {'#silentsam': {'weight': 2},
#   '#dragoncon2018': {'weight': 1},
#   '#defcon': {'weight': 1},
#   '#foxnews': {'weight': 1},
#   '#pjnet': {'weight': 1},
#   '#nra': {'weight': 1},
#   '#p2': {'weight': 1},
#   '#ccot': {'weight': 1},
#   '#tcot': {'weight': 1},
#   '#tucker': {'weight': 1},
#   '#hurricanelane': {'weight': 1},
#   '#btsonagt': {'weight': 1},
#   '#appleevent': {'weight': 1},
#   '#donaldtrump': {'weight': 1},
#   '#teachersday': {'weight': 1},
#   '#magarallyrules': {'weight': 1},
#   '#hollywood': {'weight': 1}},
#  '#unclimatesurvey': {'#silentsam': {'weight': 2}},
#  '#necessity': {'#standwithmaya': {'weight': 1}, '#silentsam': {'weight': 1}},
#  '#participationtrophies': {'#treason': {'weight': 1},
#   '#civilwar': {'weight': 1},
#   '#silentsam': {'weight': 1}},
#  '#ocbocc': {'#jeffersondavis': {'weight': 2},
#   '#confederate': {'weight': 2},
#   '#silentsam': {'weight': 2}},
#  '#wegotthis': {'#silentsam': {'weight': 202},
#   '#tearthemalldown': {'weight': 5},
#   '#students': {'weight': 5},
#   '#unc': {'weight': 5},
#   '#solidarity': {'weight': 5}},
#  '#vandals': {'#ncpol': {'weight': 1},
#   '#durham': {'weight': 4},
#   '#silentsam': {'weight': 4},
#   '#amend': {'weight': 1},
#   '#voterep': {'weight': 3}},
#  '#amend': {'#silentsam': {'weight': 1},
#   '#durham': {'weight': 1},
#   '#ncpol': {'weight': 1},
#   '#vandals': {'weight': 1}},
#  '#necessityclause': {'#silentsam': {'weight': 11}},
#  '#carolinadelnorte': {'#silentsam': {'weight': 5},
#   '#carolina': {'weight': 1},
#   '#chapelhill': {'weight': 1},
#   '#eeuu': {'weight': 1},
#   '#confederación': {'weight': 1},
#   '#soldado': {'weight': 1},
#   '#estatua': {'weight': 1},
#   '#manifestantes': {'weight': 1}},
#  '#christineblaseyfordisaliar': {'#istandwithlawandorder': {'weight': 1},
#   '#justletthestudentslearn': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#chapelhill': {'weight': 1}},
#  '#istandwithlawandorder': {'#justletthestudentslearn': {'weight': 1},
#   '#christineblaseyfordisaliar': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#chapelhill': {'weight': 1}},
#  '#justletthestudentslearn': {'#istandwithlawandorder': {'weight': 1},
#   '#christineblaseyfordisaliar': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#chapelhill': {'weight': 1}},
#  '#mondaythoughts': {'#silentsam': {'weight': 1}},
#  '#nationalpugday': {'#silentsam': {'weight': 1}},
#  '#rougekillers': {'#impeach45': {'weight': 1}, '#silentsam': {'weight': 1}},
#  '#impeach45': {'#silentsam': {'weight': 1}, '#rougekillers': {'weight': 1}},
#  '#racismistheheartattack': {'#standwithmaya': {'weight': 5},
#   '#courtsupport': {'weight': 5},
#   '#silentsam': {'weight': 5}},
#  '#courtsupport': {'#standwithmaya': {'weight': 16},
#   '#racismistheheartattack': {'weight': 5},
#   '#silentsam': {'weight': 16},
#   '#ftp': {'weight': 7},
#   '#silencesam': {'weight': 3},
#   '#crossexamination': {'weight': 2},
#   '#nocopsnoklangetridofsilentsam': {'weight': 2},
#   '#bodycamera': {'weight': 2},
#   '#whatwasthereason': {'weight': 2}},
#  '#justice4silentsam': {'#silentsam': {'weight': 1},
#   '#preservehistory': {'weight': 1},
#   '#justiceforsam': {'weight': 1}},
#  '#justiceforsam': {'#preservehistory': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#justice4silentsam': {'weight': 1}},
#  '#crossexamination': {'#silentsam': {'weight': 2},
#   '#standwithmaya': {'weight': 2},
#   '#courtsupport': {'weight': 2}},
#  '#bodycamera': {'#nocopsnoklangetridofsilentsam': {'weight': 2},
#   '#courtsupport': {'weight': 2},
#   '#ftp': {'weight': 2},
#   '#silentsam': {'weight': 2},
#   '#standwithmaya': {'weight': 2}},
#  '#nocopsnoklangetridofsilentsam': {'#courtsupport': {'weight': 2},
#   '#ftp': {'weight': 2},
#   '#bodycamera': {'weight': 2},
#   '#silentsam': {'weight': 2},
#   '#standwithmaya': {'weight': 2}},
#  '#racialcapitalism': {'#standwithmaya': {'weight': 2},
#   '#silentsam': {'weight': 2}},
#  '#whatwasthereason': {'#standwithmaya': {'weight': 2},
#   '#courtsupport': {'weight': 2},
#   '#ftp': {'weight': 2},
#   '#silentsam': {'weight': 2}},
#  '#trials': {'#bodycameras': {'weight': 4},
#   '#ftp': {'weight': 4},
#   '#silentsam': {'weight': 4},
#   '#standwithmaya': {'weight': 4}},
#  '#bodycameras': {'#ftp': {'weight': 4},
#   '#trials': {'weight': 4},
#   '#silentsam': {'weight': 4},
#   '#standwithmaya': {'weight': 4}},
#  '#healing': {'#unc225': {'weight': 1},
#   '#gdtbath': {'weight': 1},
#   '#carolina': {'weight': 1},
#   '#silentsam': {'weight': 3},
#   '#reconciliation': {'weight': 2}},
#  '#unc225': {'#gdtbath': {'weight': 1},
#   '#carolina': {'weight': 1},
#   '#healing': {'weight': 1},
#   '#silentsam': {'weight': 1}},
#  '#race': {'#silentsam': {'weight': 50},
#   '#race': {'weight': 2},
#   '#unc': {'weight': 13},
#   '#raleigh': {'weight': 2},
#   '#visitraleigh': {'weight': 2},
#   '#marktwainhouse': {'weight': 2},
#   '#slavery': {'weight': 6},
#   '#racism': {'weight': 30},
#   '#marktwain': {'weight': 1},
#   '#confederatemonuments': {'weight': 35},
#   '#confederatemonument': {'weight': 15},
#   '#charlottesville': {'weight': 35},
#   '#confederate': {'weight': 36},
#   '#talkingoreos': {'weight': 4},
#   '#rftm': {'weight': 4},
#   '#usa': {'weight': 25},
#   '#confederacy': {'weight': 2},
#   '#blackhistory': {'weight': 1},
#   '#civilwarmemory': {'weight': 1},
#   '#monuments': {'weight': 1},
#   '#statues': {'weight': 1},
#   '#politics': {'weight': 1}},
#  '#marktwainhouse': {'#visitraleigh': {'weight': 1},
#   '#raleigh': {'weight': 1},
#   '#unc': {'weight': 1},
#   '#race': {'weight': 2},
#   '#silentsam': {'weight': 1},
#   '#slavery': {'weight': 1}},
#  '#hypocrisy': {'#silentsam': {'weight': 24}, '#freespeech': {'weight': 1}},
#  '#drfraud': {'#silentsam': {'weight': 1}},
#  '#southernhistory': {'#silentsam': {'weight': 49},
#   '#malindamaynorlowery': {'weight': 1},
#   '#unc': {'weight': 1},
#   '#mayalittle': {'weight': 1},
#   '#activist': {'weight': 1},
#   '#protester': {'weight': 1}},
#  '#rustinpieces': {'#silentsam': {'weight': 5}},
#  '#j711': {'#silentsam': {'weight': 5}},
#  '#statuealreadyremoved': {'#ncpol': {'weight': 1},
#   '#silentsam': {'weight': 1}},
#  '#boycottunc': {'#unc': {'weight': 65},
#   '#silentsam': {'weight': 163},
#   '#firedwaynedixon': {'weight': 2},
#   '#dwaynedixon': {'weight': 2},
#   '#cnn': {'weight': 2},
#   '#tarheelshame': {'weight': 2},
#   '#blacklivesmatter': {'weight': 12},
#   '#racism': {'weight': 3},
#   '#uncchapelhill': {'weight': 2},
#   '#tarheels': {'weight': 4},
#   '#saturdaymorning': {'weight': 2},
#   '#getahistorylesson': {'weight': 3},
#   '#goheels': {'weight': 49},
#   '#uncforall': {'weight': 20},
#   '#gdtbath': {'weight': 46},
#   '#beatuva': {'weight': 7},
#   '#originofflight': {'weight': 7},
#   '#silencesam': {'weight': 64},
#   '#ncpol': {'weight': 52},
#   '#ncga': {'weight': 27},
#   '#defendcivilrights': {'weight': 25},
#   '#kickoutthekkk': {'weight': 19},
#   '#uva200': {'weight': 1},
#   '#confederate': {'weight': 55},
#   '#nced': {'weight': 4},
#   '#whitesupremacy': {'weight': 40},
#   '#getrealwithbsm': {'weight': 9},
#   '#uncthreezeros': {'weight': 1},
#   '#defenddurham': {'weight': 20},
#   '#winning': {'weight': 3},
#   '#beatduke': {'weight': 1},
#   '#firstdayoffall': {'weight': 1},
#   '#racist': {'weight': 12},
#   '#now': {'weight': 1},
#   '#protest': {'weight': 2}},
#  '#firedwaynedixon': {'#dwaynedixon': {'weight': 2},
#   '#silentsam': {'weight': 2},
#   '#unc': {'weight': 2},
#   '#boycottunc': {'weight': 2}},
#  '#movesilentsam': {'#silentsam': {'weight': 34},
#   '#confederate': {'weight': 2},
#   '#confederatelivesmatter': {'weight': 1},
#   '#militiafriends': {'weight': 3},
#   '#actbac': {'weight': 3},
#   '#domesticterrorism': {'weight': 1},
#   '#antifa': {'weight': 5},
#   '#iww': {'weight': 3},
#   '#splc': {'weight': 1},
#   '#unc': {'weight': 27},
#   '#notohate': {'weight': 1},
#   '#diversity': {'weight': 1},
#   '#diversityinclusion': {'weight': 1},
#   '#warmemorialdestructionishate': {'weight': 1},
#   '#defenddurham': {'weight': 1},
#   '#unctrustees': {'weight': 1},
#   '#uncbog': {'weight': 1},
#   '#racist': {'weight': 21},
#   '#silencesam': {'weight': 21}},
#  '#confederatelivesmatter': {'#confederate': {'weight': 2},
#   '#silentsam': {'weight': 2},
#   '#movesilentsam': {'weight': 1},
#   '#csa': {'weight': 1},
#   '#honorourveterans': {'weight': 1},
#   '#maga': {'weight': 1},
#   '#preservehistory': {'weight': 1}},
#  '#saturdaymorning': {'#unc': {'weight': 5},
#   '#tarheels': {'weight': 5},
#   '#silentsam': {'weight': 6},
#   '#uncchapelhill': {'weight': 5},
#   '#racism': {'weight': 5},
#   '#blacklivesmatter': {'weight': 5},
#   '#boycottunc': {'weight': 2},
#   '#cnn': {'weight': 4},
#   '#tarheelshame': {'weight': 2},
#   '#trump': {'weight': 2},
#   '#maga': {'weight': 2},
#   '#republicans': {'weight': 2},
#   '#gop': {'weight': 2},
#   '#democrats': {'weight': 3},
#   '#midtermelections2018': {'weight': 2},
#   '#midterms': {'weight': 2},
#   '#followbackresistance': {'weight': 3},
#   '#fbrparty': {'weight': 3},
#   '#bluewave': {'weight': 3},
#   '#dnc2018': {'weight': 2},
#   '#bluewave2018': {'weight': 2},
#   '#fbr': {'weight': 3},
#   '#resistance': {'weight': 3},
#   '#resist': {'weight': 3},
#   '#dnc': {'weight': 3},
#   '#hatespeech': {'weight': 1},
#   '#safertogether': {'weight': 1}},
#  '#cnn': {'#tarheelshame': {'weight': 2},
#   '#boycottunc': {'weight': 2},
#   '#blacklivesmatter': {'weight': 4},
#   '#racism': {'weight': 4},
#   '#uncchapelhill': {'weight': 4},
#   '#silentsam': {'weight': 8},
#   '#tarheels': {'weight': 4},
#   '#unc': {'weight': 8},
#   '#saturdaymorning': {'weight': 4},
#   '#democrats': {'weight': 2},
#   '#followbackresistance': {'weight': 2},
#   '#fbrparty': {'weight': 2},
#   '#bluewave': {'weight': 2},
#   '#fbr': {'weight': 2},
#   '#resistance': {'weight': 2},
#   '#resist': {'weight': 2},
#   '#dnc': {'weight': 2},
#   '#hatespeech': {'weight': 1},
#   '#trump': {'weight': 3},
#   '#maga': {'weight': 1},
#   '#republicans': {'weight': 1},
#   '#gop': {'weight': 1},
#   '#midtermelections2018': {'weight': 1},
#   '#midterms': {'weight': 1},
#   '#dnc2018': {'weight': 1},
#   '#bluewave2018': {'weight': 1},
#   '#thescandalthatneverends': {'weight': 2},
#   '#trumpderangementsyndrome': {'weight': 2},
#   '#civilwar': {'weight': 2},
#   '#police': {'weight': 2},
#   '#nolaw': {'weight': 2},
#   '#noorder': {'weight': 2},
#   '#vaping': {'weight': 2},
#   '#dna': {'weight': 2},
#   '#todayindoom': {'weight': 2},
#   '#tuesdaymotivation': {'weight': 2},
#   '#msnbc': {'weight': 1},
#   '#foxnews': {'weight': 1},
#   '#media': {'weight': 1},
#   '#cheguevara': {'weight': 1},
#   '#confederate': {'weight': 1}},
#  '#tarheelshame': {'#cnn': {'weight': 2},
#   '#boycottunc': {'weight': 2},
#   '#blacklivesmatter': {'weight': 2},
#   '#racism': {'weight': 2},
#   '#uncchapelhill': {'weight': 2},
#   '#silentsam': {'weight': 2},
#   '#tarheels': {'weight': 2},
#   '#unc': {'weight': 2},
#   '#saturdaymorning': {'weight': 2}},
#  '#foodstudies': {'#gdtbath': {'weight': 4},
#   '#silentsam': {'weight': 4},
#   '#dh': {'weight': 4}},
#  '#sacredpublicspaces': {'#silentsam': {'weight': 3}},
#  '#context': {'#campushistories': {'weight': 4}, '#silentsam': {'weight': 4}},
#  '#nashvillianswillknow': {'#silentsam': {'weight': 1}},
#  '#campushistory': {'#silentsam': {'weight': 2},
#   '#silencesam': {'weight': 1},
#   '#publichistory': {'weight': 1}},
#  '#mute': {'#punk': {'weight': 2},
#   '#documentary': {'weight': 2},
#   '#music': {'weight': 2},
#   '#silentsam': {'weight': 2}},
#  '#punk': {'#documentary': {'weight': 3},
#   '#music': {'weight': 2},
#   '#silentsam': {'weight': 3},
#   '#mute': {'weight': 2},
#   '#ladybirdband': {'weight': 1},
#   '#guardian': {'weight': 1},
#   '#ladybird': {'weight': 1}},
#  '#sacredspaces': {'#silentsam': {'weight': 2}},
#  '#gafs18': {'#foodhist': {'weight': 3},
#   '#envhist': {'weight': 3},
#   '#everythinghasahistory': {'weight': 3},
#   '#historymatters': {'weight': 3},
#   '#silentsam': {'weight': 3}},
#  '#foodhist': {'#envhist': {'weight': 3},
#   '#everythinghasahistory': {'weight': 3},
#   '#historymatters': {'weight': 3},
#   '#gafs18': {'weight': 3},
#   '#silentsam': {'weight': 3}},
#  '#envhist': {'#everythinghasahistory': {'weight': 3},
#   '#historymatters': {'weight': 3},
#   '#foodhist': {'weight': 3},
#   '#gafs18': {'weight': 3},
#   '#silentsam': {'weight': 3}},
#  '#kkk': {'#udc': {'weight': 6},
#   '#confederate': {'weight': 8},
#   '#confederatemonument': {'weight': 6},
#   '#racism': {'weight': 8},
#   '#whitesupremacy': {'weight': 7},
#   '#silentsam': {'weight': 13},
#   '#southern': {'weight': 6},
#   '#civilwar': {'weight': 6},
#   '#civilrights': {'weight': 6},
#   '#rhymecrime': {'weight': 1},
#   '#whiteklan': {'weight': 1},
#   '#confederacy': {'weight': 2},
#   '#unc': {'weight': 2},
#   '#charlottesville': {'weight': 1},
#   '#chapelhill': {'weight': 1},
#   '#dearunc': {'weight': 1},
#   '#ncga': {'weight': 1},
#   '#twitterstorians': {'weight': 1},
#   '#blktwitterstorians': {'weight': 1},
#   '#silencesam': {'weight': 1},
#   '#ncpol': {'weight': 1},
#   '#tarheels': {'weight': 1},
#   '#racist': {'weight': 3},
#   '#whitesupremacist': {'weight': 2},
#   '#bigot': {'weight': 2},
#   '#nazi': {'weight': 2}},
#  '#southern': {'#civilwar': {'weight': 6},
#   '#civilrights': {'weight': 6},
#   '#silentsam': {'weight': 6},
#   '#whitesupremacy': {'weight': 6},
#   '#racism': {'weight': 6},
#   '#confederatemonument': {'weight': 6},
#   '#confederate': {'weight': 6},
#   '#udc': {'weight': 6},
#   '#kkk': {'weight': 6}},
#  '#kenanstadium': {'#abc11': {'weight': 3}, '#silentsam': {'weight': 3}},
#  '#chpd': {'#silentsam': {'weight': 3}},
#  '#hughmcmanaway': {'#silentsam': {'weight': 2},
#   '#chapelhill': {'weight': 1},
#   '#charlottestatue': {'weight': 1}},
#  '#charlottestatue': {'#silentsam': {'weight': 1},
#   '#chapelhill': {'weight': 1},
#   '#hughmcmanaway': {'weight': 1}},
#  '#antiantifatuesday': {'#silentsam': {'weight': 1}},
#  '#taxpayers': {'#ncpol': {'weight': 10},
#   '#silentsam': {'weight': 10},
#   '#nc': {'weight': 10}},
#  '#monumentstotreason': {'#confederatemonuments': {'weight': 1},
#   '#northcarolina': {'weight': 1},
#   '#nc': {'weight': 1},
#   '#silentsam': {'weight': 1}},
#  '#ladybird': {'#guardian': {'weight': 1},
#   '#documentary': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#punk': {'weight': 1},
#   '#ladybirdband': {'weight': 1}},
#  '#guardian': {'#documentary': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#punk': {'weight': 1},
#   '#ladybirdband': {'weight': 1},
#   '#ladybird': {'weight': 1}},
#  '#ladybirdband': {'#punk': {'weight': 1},
#   '#silentsam': {'weight': 1},
#   '#documentary': {'weight': 1},
#   '#guardian': {'weight': 1},
#   '#ladybird': {'weight': 1}},
#  '#comm206': {'#silentsam': {'weight': 3}},
#  '#believechristine': {'#silentsam': {'weight': 1}},
#  '#kavanaughhearings': {'#silentsam': {'weight': 1}},
#  '#uncfree': {'#silentsam': {'weight': 2}},
#  ...}

# %%
G=nx.Graph()

# %%
G=nx.from_dict_of_dicts(d)

# %%
nx.draw(G)

# %%
d1

# %%
def buildKeys2(ls):
    for i in range(len(ls)):
        for j in range(i+1,len(ls)):
            a = ls[i].lower()
            b = ls[j].lower()
            d1.setdefault(a,{}).setdefault(b,{}).setdefault("weight",0)
            d1[a][b]['weight'] += 1

# %%
has_co.apply(buildKeys2)

# %%
d1

# %%
count=0
sum=0
for i in tuple(G1.edges(data=True)):
    count+=1
    sum+=i[2]['weight']

# %%
mean=sum/count
mean

# %%
import numpy as np

# %%
#pos=nx.graphviz_layout(G)

plt.figure(figsize=(15, 15))
#nx.draw_random(G1,node_size=20,node_color='r',alpha=0.1, with_labels=True)
SG=nx.Graph( [ (u,v,d) for u,v,d in G1.edges(data=True) if d 
['weight']>40] )

node_size = list(nx.get_node_attributes(SG, 'weight').values())
pos=nx.spring_layout(SG,scale=5)
img= nx.draw_networkx_nodes(SG, pos=pos,node_size=list(dict(SG.degree).values()),cmp=plt.cm.Reds,node_color=range(len(SG)))
img= nx.draw_networkx_edges(SG, pos=pos,node_size=list(dict(SG.degree).values()),alpha=0.3)
pos2=pos
for i in pos2.values():
    i[1]+=0.16
img= nx.draw_networkx_labels(SG, pos=pos2,font_size=12)
plt.title("Co-occurrence Network of the Hashtages with 40 or Higher Edge Weights")

#get

# %%
pos2=pos
for i in pos2.values():
    i[1]+=0.01

# %%
[i for i in tw_has if len(i)>2]

# %%
db.text[3]

# %%
def gen_dic(ls):
    size=len(ls)
    for i in ls:
        temp=ls.remove
