# %%
import pandas as pd

# %%
user_set=pd.read_csv("Users with Nor Loc.csv")
# Out:
# c:\python36\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
user_set.tweets_num.describe()
# Out:
# count    26098.000000
# mean         2.265938
# std         12.392065
# min        -79.562596
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max       1271.000000
# Name: tweets_num, dtype: float64

# %%
user_set.sort_values(by="tweets_num", ascending=False).iloc[0:102,:]
# Out:
#     Unnamed: 0 user_screen_name  tweets_num               id_str  \
# 0            0  Move_Silent_Sam      1271.0  1098971801378582529
# 1            1       LocoCravey       799.0  1099674637695414272
# 2            2   AlyssaAnnBowen       738.0  1096082833792212992
# 3            3      ssiddiqui83       260.0  1099857355485995008
# 4            4           jdmar3       254.0  1085902075228123137
# 5            5   WCHLChapelboro       234.0  1099323999975292928
# 6            6     getsthegoods       230.0  1099695310316756993
# 7            7       pointblaek       207.0  1098962036292235265
# 8            8     jerryjwilson       204.0  1097131514377236481
# 9            9  Stop_UNC_Racism       191.0  1074839730737635328
# 10          10     newsobserver       176.0  1099032858029633536
# 12          12     JoekillianPW       148.0  1091417602474143745
# 11          11         m1523751       148.0  1099512491271442432
# ...

# %%
#this would be our node list
top_100_user_set=user_set.sort_values(by="tweets_num", ascending=False).iloc[0:102,:]

# %%
userlist=top_100_user_set.from_user.tolist()

# %%
#read edge list
sam_all= pd.read_csv("sam_all_edgelist.csv")

# %%
sam_all.columns=["ind","from","to"]

# %%
sam_all[sam_all["from"].isin(userlist)&sam_all["to"].isin(userlist)]
# Out:
#          ind             from              to
# 38        38  takethemdownnow  jordangreentcb
# 46        46  takethemdownnow  jordangreentcb
# 48        48       chogmorson  jordangreentcb
# 49        49       dhosterman  jordangreentcb
# 53        53     getsthegoods  jordangreentcb
# 66        66  margaretcmaurer  jordangreentcb
# 84        84     takeactionch    newsobserver
# 115      115      ssiddiqui83  jordangreentcb
# 118      118     takeactionch  jordangreentcb
# 143      143         m1523751  jordangreentcb
# 144      144         underoak  jordangreentcb
# 170      170      triangleiww  jordangreentcb
# 171      171       chogmorson  jordangreentcb
# 183      183     jerryjwilson  jordangreentcb
# 199      199         gilletgr  jordangreentcb
# 210      210     getsthegoods  jordangreentcb
# 263      263     takeactionch      nanfulcher
# 1458    1458          sirtou2    getsthegoods
# 1565    1565         m1523751  jordangreentcb
# ...

# %%
top_100_user_edge_list=sam_all[sam_all["from"].isin(userlist)&sam_all["to"].isin(userlist)]

# %%
top_100_user_set.to_csv("top100nodes.csv")
top_100_user_edge_list.to_csv("top100edges.csv")
